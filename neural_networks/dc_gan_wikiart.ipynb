# %% [markdown]
# ### Wikiart: Deep Convolutional (DC) Generative Adverserial Network (GAN)

# %% [markdown]
# ### Load Libraries

# %%
import torchvision
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils import data
from torch.utils.data import DataLoader
from google.colab import drive
import argparse
import os
from os import walk
import random
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import torchvision.transforms as transforms
import torchvision.utils as vutils
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
import time
import sys
import tensorflow as tf

# %% [markdown]
# ### Mount Google Drive

# %%
# mount drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Load Metric Modules

# %%
# load inception score metric
inception_path = '/content/drive/MyDrive/neural_networks/modules/inception_score_pytorch'
#!cat '/content/drive/MyDrive/neural_networks/modules/inception_score_pytorch/inception_score.py'
sys.path.append(inception_path)
from inception_score import inception_score
frechet_path = '/content/drive/MyDrive/neural_networks/modules/frechet_inception_distance'
#!cat '/content/drive/MyDrive/neural_networks/modules/frechet_inception_distance/frechet_inception_distance.py'
sys.path.append(frechet_path)
from frechet_inception_distance import frechet_id
fractal_path = '/content/drive/MyDrive/neural_networks/modules/fractal_image_compression'
#!cat '/content/drive/MyDrive/neural_networks/modules/fractal_image_compression/compression.py'
sys.path.append(fractal_path)
from fracal_image_compression import compression

# %% [markdown]
# ### Training Parameters

# %%
num_epochs = 200
batch_size = 64
learning_rate = 2e-4
use_gpu = True
img_size = 64
device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")
tolerance = 0.0001
# use smaller wiki art data for testing
use_test_data = True

# %% [markdown]
# ### Load Subset Wikiart Data

# %%
# print subfolders/art styles of the wikiart subset directory
#!ls '/content/drive/MyDrive/neural_networks/data/wikiart_resized'
# set parent folder of wikiart as file directory
if use_test_data == True:
    data_dir = '/content/drive/MyDrive/neural_networks/data/wikiart_subset'

elif use_test_data == False:
    data_dir = '/content/drive/MyDrive/neural_networks/data/wikiart_resized'

# set random seed
random.seed(1486438)
torch.manual_seed(1486438)

# define transformer for data loader
# resize and normalize data for slight performance boost
img_transform = transforms.Compose([
                                    transforms.Resize((img_size, img_size)),
                                    transforms.ToTensor(),
                                    transforms.Normalize((0.5, 0.5, 0.5), 
                                                         (0.5, 0.5, 0.5))
                                  ])

dataset = datasets.ImageFolder(root=data_dir,
                           transform=img_transform)
# Create the dataloader
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                         shuffle=True)

# Plot some training images
real_batch = next(iter(dataloader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device), padding=2, 
                                         normalize=True).cpu(),(1,2,0)))

# %% [markdown]
# ### Custom Weight Initialization

# %%
# custom weights initialization called on netG and netD
# set random seed
random.seed(1486438)
torch.manual_seed(1486438)
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %% [markdown]
# ### Gan Parameters

# %%
# number of channels (1 = gray, 3 = RGB colors)
nc = 3
# number/size of latent vector z for the generator input
nz = 100
# size/number of feature maps in generator
ngf = 64
# size/number of feature maps in discriminator
ndf = 64
# define fixed noise to sample images from the latent space of the generator
fixed_noise = torch.randn(64, nz, 1, 1, device=device)

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        # input to conv. lay. : length of latent vector z 
        self.deconv1 = nn.ConvTranspose2d(nz, ngf*8, 4, 1, 0, bias=False)
        self.deconv1_bn = nn.BatchNorm2d(ngf*8)
        # state size: (ngf * 8) x 4 x 4
        self.deconv2 = nn.ConvTranspose2d(ngf*8, ngf*4, 4, 2, 1, bias=False)
        self.deconv2_bn = nn.BatchNorm2d(ngf*4)
        # state size: (ngf * 4) x 8 x 8
        self.deconv3 = nn.ConvTranspose2d(ngf*4, ngf*2, 4, 2, 1, bias=False)
        self.deconv3_bn = nn.BatchNorm2d(ngf*2)
        # state size: (ngf * 2) x 16 x 16
        self.deconv4 = nn.ConvTranspose2d(ngf*2, ngf, 4, 2, 1, bias=False)
        self.deconv4_bn = nn.BatchNorm2d(ngf)
        # state size: (ngf) x 32 x 32
        self.deconv5 = nn.ConvTranspose2d(ngf, nc, 4, 2, 1, bias=False)
        # state size: (nc) x 64 x 64

    def forward(self, input):
        x = F.relu(self.deconv1(input))
        x = F.relu(self.deconv1_bn(self.deconv1(input)))
        x = F.relu(self.deconv2_bn(self.deconv2(x)))
        x = F.relu(self.deconv3_bn(self.deconv3(x)))
        x = F.relu(self.deconv4_bn(self.deconv4(x)))
        x = torch.tanh(self.deconv5(x))
        return x

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        # input to conv. lay. : (nc) x 64 x 64
        self.conv1 = nn.Conv2d(nc, ndf, 4, 2, 1, bias=False)
        self.conv1_bn = nn.BatchNorm2d(ndf)
        # state size: (ndf) x 32 x 32
        self.conv2 = nn.Conv2d(ndf, ndf*2, 4, 2, 1, bias=False)
        self.conv2_bn = nn.BatchNorm2d(ndf*2)
        # state size: (ndf * 2) x 16 x 16
        self.conv3 = nn.Conv2d(ndf*2, ndf*4, 4, 2, 1, bias=False)
        self.conv3_bn = nn.BatchNorm2d(ndf*4)
        # state size: (ndf * 4) x 8 x 8
        self.conv4 = nn.Conv2d(ndf*4, ndf*8, 4, 2, 1, bias=False)
        self.conv4_bn = nn.BatchNorm2d(ndf*8)
        # state size: (ndf * 8) x 4 x 4
        self.conv5 = nn.Conv2d(ndf*8, 1, 4, 1, 0, bias=False)

    def forward(self, input):
        x = F.leaky_relu(self.conv1(input))
        x = F.leaky_relu(self.conv1_bn(self.conv1(input)), 0.2)
        x = F.leaky_relu(self.conv2_bn(self.conv2(x)), 0.2)
        x = F.leaky_relu(self.conv3_bn(self.conv3(x)), 0.2)
        x = F.leaky_relu(self.conv4_bn(self.conv4(x)), 0.2)
        x = torch.sigmoid(self.conv5(x))
        return x
    
generator = Generator()
discriminator = Discriminator()

# apply the weights_init function to randomly initialize all weights
# to mean=0, stdev=0.02
# set random seed
#random.seed(1486438)
#torch.manual_seed(1486438)
generator.apply(weights_init)
discriminator.apply(weights_init)

device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")
generator = generator.to(device)
discriminator = discriminator.to(device)

num_params_gen = sum(p.numel() for p in generator.parameters() if p.requires_grad)
num_params_disc = sum(p.numel() for p in discriminator.parameters() if p.requires_grad)
print('Number of parameters for generator: %d and discriminator: %d' % (num_params_gen, num_params_disc))
# Out:
# Number of parameters for generator: 3576704 and discriminator: 2765696

# %% [markdown]
# ### Define Storage Location

# %%
# mount google drive for saving checkpoints
drive.mount('/content/drive')

# checkpoint generator file name
gen_save_name = 'wikiart_dc_gen.cpt'
# define location to store checkpoints for generator
path_gen = F'/content/drive/MyDrive/neural_networks/checkpoints/{gen_save_name}'

# checkpoint discriminator file name
disc_save_name = 'wikiart_dc_disc.cpt'
# define location to store checkpoints for discriminator
path_disc = F'/content/drive/MyDrive/neural_networks/checkpoints/{disc_save_name}'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Train GAN

# %%
gen_optimizer = torch.optim.Adam(params=generator.parameters(), lr=learning_rate,
                                 betas=(0.5, 0.999))
disc_optimizer = torch.optim.Adam(params=discriminator.parameters(), lr=learning_rate,
                                  betas=(0.5, 0.999))
# set to training mode
generator.train()
discriminator.train()

# loss per iteration
gen_iter_loss = []
disc_iter_loss = []
#loss per epoch
gen_loss_avg = []
disc_loss_avg = []

gen_loss_avg.append(0)
disc_loss_avg.append(0)

iters = 0

# store generated images 
img_lst = []
# store generated images for gif
img_lst_gif = []

print('Training ...')
for epoch in range(num_epochs):
    # start countine time 
    start_time = time.time() 
    gen_loss_avg.append(0)
    disc_loss_avg.append(0)
    num_batches = 0
    
    for image_batch, i in dataloader:
        
        # get dataset image and create real and fake labels for use in the loss
        image_batch = image_batch.to(device)
        label_real = torch.ones(image_batch.size(0), device=device)
        label_fake = torch.zeros(image_batch.size(0), device=device)

        # generate a batch of images from samples of the latent prior
        latent = torch.randn(image_batch.size(0), nz, 1, 1, device=device)
        fake_image_batch = generator(latent)
        
        # train discriminator to correctly classify real and fake
        # (detach the computation graph of the generator and the discriminator,
        # so that gradients are not backpropagated into the generator)
        real_pred = discriminator(image_batch).squeeze()
        fake_pred = discriminator(fake_image_batch.detach()).squeeze()
        disc_loss = 0.5 * (
            F.binary_cross_entropy(real_pred, label_real) +
            F.binary_cross_entropy(fake_pred, label_fake))
        
        disc_optimizer.zero_grad()
        disc_loss.backward()
        disc_optimizer.step()
        
        # train generator to output an image that is classified as real
        fake_pred = discriminator(fake_image_batch).squeeze()
        gen_loss = F.binary_cross_entropy(fake_pred, label_real)
        
        gen_optimizer.zero_grad()
        gen_loss.backward()
        gen_optimizer.step()
        
        # loss per iteration
        gen_iter_loss.append(gen_loss.item())
        disc_iter_loss.append(disc_loss.item())

        # average loss per iteration to obtain average loss per epoch
        gen_loss_avg[-1] += gen_loss.item()
        disc_loss_avg[-1] += disc_loss.item()
        num_batches += 1
        # every 40 batches give print statement
        if num_batches % 127 == 0 :
            print('Epoch [%d / %d], batch [%d / %d]: average loss generator vs. discrim.: %f vs. %f [%s seconds]' %
          (epoch+1, num_epochs, num_batches, len(dataloader), gen_loss_avg[-1], disc_loss_avg[-1], round(time.time() - start_time,3)))
            print('No. of sample images stored: [%d]' % len(img_lst))
        # Save generated image if: 
        # 1) at the first iteration
        # 2) final epoch has been reached
        # 3) a full batch of training passed i.e one epoch has passed
        elif (iters == 1) or (epoch == num_epochs) or (iters % len(dataloader) == 0):
            # turn off gradient descent computation to minimize computation cost
            with torch.no_grad():
                # generate fake image from generator
                fake = generator(fixed_noise).detach().cpu()
            # store image
            img_lst.append(fake)
            # store image for gif
            img_lst_gif.append(vutils.make_grid(fake, padding=2, normalize=True))
            print('No. of sample images stored: [%d]' % len(img_lst))
        iters += 1
    gen_loss_avg[-1] /= num_batches
    disc_loss_avg[-1] /= num_batches
    # after each epoch print current epoch, generator and discriminator loss and runtime per epoch
    print('Epoch [%d / %d] average loss generator vs. discrim.: %f vs. %f [%s seconds]'  %
          (epoch+1, num_epochs, gen_loss_avg[-1], disc_loss_avg[-1], round(time.time() - start_time,3)))
    # after each epoch save generator, epochs, loss and images
    print('Generator Checkpoint Saved [%d / %d]' % (epoch + 1, num_epochs))
    torch.save({
            'epoch': epoch,
            'gen_state_dict': generator.state_dict(),
            'optimizer_state_dict': gen_optimizer.state_dict(),
            'gen_loss_avg': gen_loss_avg,
            'gen_iter_loss': gen_iter_loss,
            'img_lst': img_lst,
            'img_lst_gif': img_lst_gif,
            }, path_gen)
    # after each epoch save discriminator, epochs and loss
    print('Discriminator Checkpoint Saved [%d / %d]' % (epoch + 1, num_epochs))
    torch.save({
            'epoch': epoch,
            'disc_state_dict': discriminator.state_dict(),
            'optimizer_state_dict': disc_optimizer.state_dict(),
            'disc_loss_avg': disc_loss_avg,
            'disc_iter_loss': disc_iter_loss,
            }, path_disc)
    # if difference between current average loss and previous average loss smaler 
    # than tolerance value stop training
    if (abs(disc_loss_avg[-1] - disc_loss_avg[-2]) <= tolerance) or (abs(gen_loss_avg[-1] - gen_loss_avg[-2]) <= tolerance):
        print('Generator or Discriminator reached an average loss of approximately 0.')
        print('One of the advaseries/players won the min-max game.')
        print('The game is over.')
        break
# Out:
# Training ...
# No. of sample images stored: [1]
# No. of sample images stored: [2]
# Epoch [1 / 200], batch [127 / 246]: average loss generator vs. discrim.: 1034.433998 vs. 48.266130 [21.588 seconds]
# No. of sample images stored: [2]
# Epoch [1 / 200] average loss generator vs. discrim.: 7.347411 vs. 0.326046 [41.013 seconds]
# Generator Checkpoint Saved [1 / 200]
# Discriminator Checkpoint Saved [1 / 200]
# No. of sample images stored: [3]
# Epoch [2 / 200], batch [127 / 246]: average loss generator vs. discrim.: 871.924989 vs. 25.952516 [20.869 seconds]
# No. of sample images stored: [3]
# Epoch [2 / 200] average loss generator vs. discrim.: 5.571044 vs. 0.275966 [40.539 seconds]
# Generator Checkpoint Saved [2 / 200]
# Discriminator Checkpoint Saved [2 / 200]
# No. of sample images stored: [4]
# Epoch [3 / 200], batch [127 / 246]: average loss generator vs. discrim.: 614.774563 vs. 45.149564 [21.068 seconds]
# No. of sample images stored: [4]
# Epoch [3 / 200] average loss generator vs. discrim.: 4.872458 vs. 0.337787 [40.825 seconds]
# Generator Checkpoint Saved [3 / 200]
# Discriminator Checkpoint Saved [3 / 200]
# No. of sample images stored: [5]
# Epoch [4 / 200], batch [127 / 246]: average loss generator vs. discrim.: 698.145888 vs. 34.051374 [20.926 seconds]
# No. of sample images stored: [5]
# Epoch [4 / 200] average loss generator vs. discrim.: 5.263677 vs. 0.295603 [40.109 seconds]
# Generator Checkpoint Saved [4 / 200]
# Discriminator Checkpoint Saved [4 / 200]
# No. of sample images stored: [6]
# Epoch [5 / 200], batch [127 / 246]: average loss generator vs. discrim.: 641.636110 vs. 30.541736 [21.167 seconds]
# No. of sample images stored: [6]
# Epoch [5 / 200] average loss generator vs. discrim.: 4.897031 vs. 0.269726 [40.581 seconds]
# Generator Checkpoint Saved [5 / 200]
# Discriminator Checkpoint Saved [5 / 200]
# No. of sample images stored: [7]
# Epoch [6 / 200], batch [127 / 246]: average loss generator vs. discrim.: 614.337478 vs. 35.407629 [21.03 seconds]
# No. of sample images stored: [7]
# Epoch [6 / 200] average loss generator vs. discrim.: 4.901090 vs. 0.270180 [40.271 seconds]
# Generator Checkpoint Saved [6 / 200]
# Discriminator Checkpoint Saved [6 / 200]
# No. of sample images stored: [8]
# Epoch [7 / 200], batch [127 / 246]: average loss generator vs. discrim.: 629.752196 vs. 33.122545 [21.04 seconds]
# No. of sample images stored: [8]
# Epoch [7 / 200] average loss generator vs. discrim.: 4.905723 vs. 0.291566 [40.234 seconds]
# Generator Checkpoint Saved [7 / 200]
# Discriminator Checkpoint Saved [7 / 200]
# No. of sample images stored: [9]
# Epoch [8 / 200], batch [127 / 246]: average loss generator vs. discrim.: 535.283491 vs. 39.612239 [20.692 seconds]
# No. of sample images stored: [9]
# Epoch [8 / 200] average loss generator vs. discrim.: 4.137142 vs. 0.339814 [39.685 seconds]
# Generator Checkpoint Saved [8 / 200]
# Discriminator Checkpoint Saved [8 / 200]
# No. of sample images stored: [10]
# Epoch [9 / 200], batch [127 / 246]: average loss generator vs. discrim.: 505.883685 vs. 41.104154 [20.286 seconds]
# No. of sample images stored: [10]
# Epoch [9 / 200] average loss generator vs. discrim.: 4.202506 vs. 0.296171 [39.482 seconds]
# Generator Checkpoint Saved [9 / 200]
# Discriminator Checkpoint Saved [9 / 200]
# No. of sample images stored: [11]
# Epoch [10 / 200], batch [127 / 246]: average loss generator vs. discrim.: 510.839522 vs. 45.274210 [21.024 seconds]
# No. of sample images stored: [11]
# Epoch [10 / 200] average loss generator vs. discrim.: 4.039876 vs. 0.341090 [40.347 seconds]
# Generator Checkpoint Saved [10 / 200]
# Discriminator Checkpoint Saved [10 / 200]
# No. of sample images stored: [12]
# Epoch [11 / 200], batch [127 / 246]: average loss generator vs. discrim.: 532.713746 vs. 35.104625 [20.515 seconds]
# No. of sample images stored: [12]
# Epoch [11 / 200] average loss generator vs. discrim.: 4.144314 vs. 0.266635 [39.491 seconds]
# Generator Checkpoint Saved [11 / 200]
# Discriminator Checkpoint Saved [11 / 200]
# No. of sample images stored: [13]
# Epoch [12 / 200], batch [127 / 246]: average loss generator vs. discrim.: 577.869756 vs. 30.943350 [20.568 seconds]
# No. of sample images stored: [13]
# Epoch [12 / 200] average loss generator vs. discrim.: 4.597701 vs. 0.261561 [39.889 seconds]
# Generator Checkpoint Saved [12 / 200]
# Discriminator Checkpoint Saved [12 / 200]
# No. of sample images stored: [14]
# Epoch [13 / 200], batch [127 / 246]: average loss generator vs. discrim.: 501.187158 vs. 31.974507 [21.259 seconds]
# No. of sample images stored: [14]
# Epoch [13 / 200] average loss generator vs. discrim.: 4.209645 vs. 0.234811 [40.962 seconds]
# Generator Checkpoint Saved [13 / 200]
# Discriminator Checkpoint Saved [13 / 200]
# No. of sample images stored: [15]
# Epoch [14 / 200], batch [127 / 246]: average loss generator vs. discrim.: 574.925782 vs. 33.999263 [21.234 seconds]
# No. of sample images stored: [15]
# Epoch [14 / 200] average loss generator vs. discrim.: 4.536509 vs. 0.253746 [39.956 seconds]
# Generator Checkpoint Saved [14 / 200]
# Discriminator Checkpoint Saved [14 / 200]
# No. of sample images stored: [16]
# Epoch [15 / 200], batch [127 / 246]: average loss generator vs. discrim.: 526.564856 vs. 36.039633 [21.002 seconds]
# No. of sample images stored: [16]
# Epoch [15 / 200] average loss generator vs. discrim.: 4.159206 vs. 0.272262 [39.812 seconds]
# Generator Checkpoint Saved [15 / 200]
# Discriminator Checkpoint Saved [15 / 200]
# No. of sample images stored: [17]
# Epoch [16 / 200], batch [127 / 246]: average loss generator vs. discrim.: 549.830855 vs. 33.477770 [20.646 seconds]
# No. of sample images stored: [17]
# Epoch [16 / 200] average loss generator vs. discrim.: 4.254470 vs. 0.277800 [40.1 seconds]
# Generator Checkpoint Saved [16 / 200]
# Discriminator Checkpoint Saved [16 / 200]
# No. of sample images stored: [18]
# Epoch [17 / 200], batch [127 / 246]: average loss generator vs. discrim.: 502.525858 vs. 37.174230 [21.039 seconds]
# No. of sample images stored: [18]
# Epoch [17 / 200] average loss generator vs. discrim.: 4.034272 vs. 0.275734 [40.549 seconds]
# Generator Checkpoint Saved [17 / 200]
# Discriminator Checkpoint Saved [17 / 200]
# No. of sample images stored: [19]
# Epoch [18 / 200], batch [127 / 246]: average loss generator vs. discrim.: 511.670432 vs. 39.503306 [20.876 seconds]
# No. of sample images stored: [19]
# Epoch [18 / 200] average loss generator vs. discrim.: 3.893011 vs. 0.283087 [39.942 seconds]
# Generator Checkpoint Saved [18 / 200]
# Discriminator Checkpoint Saved [18 / 200]
# No. of sample images stored: [20]
# Epoch [19 / 200], batch [127 / 246]: average loss generator vs. discrim.: 518.397337 vs. 29.337107 [20.437 seconds]
# No. of sample images stored: [20]
# Epoch [19 / 200] average loss generator vs. discrim.: 4.100104 vs. 0.253768 [39.569 seconds]
# Generator Checkpoint Saved [19 / 200]
# Discriminator Checkpoint Saved [19 / 200]
# No. of sample images stored: [21]
# Epoch [20 / 200], batch [127 / 246]: average loss generator vs. discrim.: 527.714067 vs. 33.372768 [20.792 seconds]
# No. of sample images stored: [21]
# Epoch [20 / 200] average loss generator vs. discrim.: 4.209822 vs. 0.242304 [39.688 seconds]
# Generator Checkpoint Saved [20 / 200]
# Discriminator Checkpoint Saved [20 / 200]
# No. of sample images stored: [22]
# Epoch [21 / 200], batch [127 / 246]: average loss generator vs. discrim.: 540.869264 vs. 36.327202 [20.859 seconds]
# No. of sample images stored: [22]
# Epoch [21 / 200] average loss generator vs. discrim.: 4.350205 vs. 0.273273 [39.629 seconds]
# Generator Checkpoint Saved [21 / 200]
# Discriminator Checkpoint Saved [21 / 200]
# No. of sample images stored: [23]
# Epoch [22 / 200], batch [127 / 246]: average loss generator vs. discrim.: 505.654470 vs. 27.797122 [20.278 seconds]
# No. of sample images stored: [23]
# Epoch [22 / 200] average loss generator vs. discrim.: 4.063943 vs. 0.246751 [39.085 seconds]
# Generator Checkpoint Saved [22 / 200]
# Discriminator Checkpoint Saved [22 / 200]
# No. of sample images stored: [24]
# Epoch [23 / 200], batch [127 / 246]: average loss generator vs. discrim.: 539.681918 vs. 28.341963 [21.019 seconds]
# No. of sample images stored: [24]
# Epoch [23 / 200] average loss generator vs. discrim.: 4.368728 vs. 0.221694 [39.906 seconds]
# Generator Checkpoint Saved [23 / 200]
# Discriminator Checkpoint Saved [23 / 200]
# No. of sample images stored: [25]
# Epoch [24 / 200], batch [127 / 246]: average loss generator vs. discrim.: 545.915741 vs. 30.926689 [20.609 seconds]
# No. of sample images stored: [25]
# Epoch [24 / 200] average loss generator vs. discrim.: 4.390163 vs. 0.246774 [39.86 seconds]
# Generator Checkpoint Saved [24 / 200]
# Discriminator Checkpoint Saved [24 / 200]
# No. of sample images stored: [26]
# Epoch [25 / 200], batch [127 / 246]: average loss generator vs. discrim.: 532.311369 vs. 21.124158 [20.922 seconds]
# No. of sample images stored: [26]
# Epoch [25 / 200] average loss generator vs. discrim.: 4.345418 vs. 0.185922 [39.938 seconds]
# Generator Checkpoint Saved [25 / 200]
# Discriminator Checkpoint Saved [25 / 200]
# No. of sample images stored: [27]
# Epoch [26 / 200], batch [127 / 246]: average loss generator vs. discrim.: 570.024055 vs. 27.730850 [21.059 seconds]
# No. of sample images stored: [27]
# Epoch [26 / 200] average loss generator vs. discrim.: 4.544341 vs. 0.257280 [40.087 seconds]
# Generator Checkpoint Saved [26 / 200]
# Discriminator Checkpoint Saved [26 / 200]
# No. of sample images stored: [28]
# Epoch [27 / 200], batch [127 / 246]: average loss generator vs. discrim.: 527.310364 vs. 20.605201 [20.663 seconds]
# No. of sample images stored: [28]
# Epoch [27 / 200] average loss generator vs. discrim.: 4.405988 vs. 0.177803 [39.491 seconds]
# Generator Checkpoint Saved [27 / 200]
# Discriminator Checkpoint Saved [27 / 200]
# No. of sample images stored: [29]
# Epoch [28 / 200], batch [127 / 246]: average loss generator vs. discrim.: 543.665146 vs. 24.244818 [20.424 seconds]
# No. of sample images stored: [29]
# Epoch [28 / 200] average loss generator vs. discrim.: 4.283301 vs. 0.205712 [39.78 seconds]
# Generator Checkpoint Saved [28 / 200]
# Discriminator Checkpoint Saved [28 / 200]
# No. of sample images stored: [30]
# Epoch [29 / 200], batch [127 / 246]: average loss generator vs. discrim.: 548.843729 vs. 31.237007 [20.701 seconds]
# No. of sample images stored: [30]
# Epoch [29 / 200] average loss generator vs. discrim.: 4.181719 vs. 0.235626 [39.479 seconds]
# Generator Checkpoint Saved [29 / 200]
# Discriminator Checkpoint Saved [29 / 200]
# No. of sample images stored: [31]
# Epoch [30 / 200], batch [127 / 246]: average loss generator vs. discrim.: 528.356679 vs. 20.782720 [20.747 seconds]
# No. of sample images stored: [31]
# Epoch [30 / 200] average loss generator vs. discrim.: 4.229461 vs. 0.202359 [39.398 seconds]
# Generator Checkpoint Saved [30 / 200]
# Discriminator Checkpoint Saved [30 / 200]
# No. of sample images stored: [32]
# Epoch [31 / 200], batch [127 / 246]: average loss generator vs. discrim.: 520.593004 vs. 27.352803 [20.474 seconds]
# No. of sample images stored: [32]
# Epoch [31 / 200] average loss generator vs. discrim.: 4.205789 vs. 0.237262 [39.093 seconds]
# Generator Checkpoint Saved [31 / 200]
# Discriminator Checkpoint Saved [31 / 200]
# No. of sample images stored: [33]
# Epoch [32 / 200], batch [127 / 246]: average loss generator vs. discrim.: 481.341922 vs. 17.747765 [20.462 seconds]
# No. of sample images stored: [33]
# Epoch [32 / 200] average loss generator vs. discrim.: 4.032867 vs. 0.162638 [39.091 seconds]
# Generator Checkpoint Saved [32 / 200]
# Discriminator Checkpoint Saved [32 / 200]
# No. of sample images stored: [34]
# Epoch [33 / 200], batch [127 / 246]: average loss generator vs. discrim.: 525.900645 vs. 33.216755 [20.947 seconds]
# No. of sample images stored: [34]
# Epoch [33 / 200] average loss generator vs. discrim.: 4.055134 vs. 0.253507 [39.883 seconds]
# Generator Checkpoint Saved [33 / 200]
# Discriminator Checkpoint Saved [33 / 200]
# No. of sample images stored: [35]
# Epoch [34 / 200], batch [127 / 246]: average loss generator vs. discrim.: 501.429347 vs. 16.491037 [20.664 seconds]
# No. of sample images stored: [35]
# Epoch [34 / 200] average loss generator vs. discrim.: 4.062579 vs. 0.188130 [39.275 seconds]
# Generator Checkpoint Saved [34 / 200]
# Discriminator Checkpoint Saved [34 / 200]
# No. of sample images stored: [36]
# Epoch [35 / 200], batch [127 / 246]: average loss generator vs. discrim.: 512.582204 vs. 30.830204 [20.658 seconds]
# No. of sample images stored: [36]
# Epoch [35 / 200] average loss generator vs. discrim.: 4.089161 vs. 0.213405 [39.857 seconds]
# Generator Checkpoint Saved [35 / 200]
# Discriminator Checkpoint Saved [35 / 200]
# No. of sample images stored: [37]
# Epoch [36 / 200], batch [127 / 246]: average loss generator vs. discrim.: 516.684575 vs. 25.740029 [21.072 seconds]
# No. of sample images stored: [37]
# Epoch [36 / 200] average loss generator vs. discrim.: 4.135947 vs. 0.264961 [39.427 seconds]
# Generator Checkpoint Saved [36 / 200]
# Discriminator Checkpoint Saved [36 / 200]
# No. of sample images stored: [38]
# Epoch [37 / 200], batch [127 / 246]: average loss generator vs. discrim.: 481.087958 vs. 18.930732 [20.242 seconds]
# No. of sample images stored: [38]
# Epoch [37 / 200] average loss generator vs. discrim.: 3.923652 vs. 0.243835 [38.773 seconds]
# Generator Checkpoint Saved [37 / 200]
# Discriminator Checkpoint Saved [37 / 200]
# No. of sample images stored: [39]
# Epoch [38 / 200], batch [127 / 246]: average loss generator vs. discrim.: 473.663612 vs. 18.936275 [20.155 seconds]
# No. of sample images stored: [39]
# Epoch [38 / 200] average loss generator vs. discrim.: 3.884873 vs. 0.142852 [38.652 seconds]
# Generator Checkpoint Saved [38 / 200]
# Discriminator Checkpoint Saved [38 / 200]
# No. of sample images stored: [40]
# Epoch [39 / 200], batch [127 / 246]: average loss generator vs. discrim.: 556.595214 vs. 47.147251 [20.586 seconds]
# No. of sample images stored: [40]
# Epoch [39 / 200] average loss generator vs. discrim.: 4.040923 vs. 0.289502 [39.198 seconds]
# Generator Checkpoint Saved [39 / 200]
# Discriminator Checkpoint Saved [39 / 200]
# No. of sample images stored: [41]
# Epoch [40 / 200], batch [127 / 246]: average loss generator vs. discrim.: 499.210764 vs. 14.065499 [20.492 seconds]
# No. of sample images stored: [41]
# Epoch [40 / 200] average loss generator vs. discrim.: 4.177389 vs. 0.198490 [39.313 seconds]
# Generator Checkpoint Saved [40 / 200]
# Discriminator Checkpoint Saved [40 / 200]
# No. of sample images stored: [42]
# Epoch [41 / 200], batch [127 / 246]: average loss generator vs. discrim.: 503.317580 vs. 20.205825 [20.354 seconds]
# No. of sample images stored: [42]
# Epoch [41 / 200] average loss generator vs. discrim.: 3.976615 vs. 0.132685 [38.719 seconds]
# Generator Checkpoint Saved [41 / 200]
# Discriminator Checkpoint Saved [41 / 200]
# No. of sample images stored: [43]
# Epoch [42 / 200], batch [127 / 246]: average loss generator vs. discrim.: 561.533933 vs. 37.380115 [20.489 seconds]
# No. of sample images stored: [43]
# Epoch [42 / 200] average loss generator vs. discrim.: 4.202983 vs. 0.221509 [38.926 seconds]
# Generator Checkpoint Saved [42 / 200]
# Discriminator Checkpoint Saved [42 / 200]
# No. of sample images stored: [44]
# Epoch [43 / 200], batch [127 / 246]: average loss generator vs. discrim.: 554.788933 vs. 32.051536 [20.89 seconds]
# No. of sample images stored: [44]
# Epoch [43 / 200] average loss generator vs. discrim.: 4.197327 vs. 0.225828 [39.828 seconds]
# Generator Checkpoint Saved [43 / 200]
# Discriminator Checkpoint Saved [43 / 200]
# No. of sample images stored: [45]
# Epoch [44 / 200], batch [127 / 246]: average loss generator vs. discrim.: 518.848628 vs. 16.522724 [20.594 seconds]
# No. of sample images stored: [45]
# Epoch [44 / 200] average loss generator vs. discrim.: 4.149130 vs. 0.140429 [40.195 seconds]
# Generator Checkpoint Saved [44 / 200]
# Discriminator Checkpoint Saved [44 / 200]
# No. of sample images stored: [46]
# Epoch [45 / 200], batch [127 / 246]: average loss generator vs. discrim.: 542.194034 vs. 32.180916 [20.973 seconds]
# No. of sample images stored: [46]
# Epoch [45 / 200] average loss generator vs. discrim.: 4.269320 vs. 0.183025 [39.708 seconds]
# Generator Checkpoint Saved [45 / 200]
# Discriminator Checkpoint Saved [45 / 200]
# No. of sample images stored: [47]
# Epoch [46 / 200], batch [127 / 246]: average loss generator vs. discrim.: 560.326496 vs. 17.311782 [20.61 seconds]
# No. of sample images stored: [47]
# Epoch [46 / 200] average loss generator vs. discrim.: 4.401702 vs. 0.231579 [39.668 seconds]
# Generator Checkpoint Saved [46 / 200]
# Discriminator Checkpoint Saved [46 / 200]
# No. of sample images stored: [48]
# Epoch [47 / 200], batch [127 / 246]: average loss generator vs. discrim.: 523.128531 vs. 11.442361 [20.815 seconds]
# No. of sample images stored: [48]
# Epoch [47 / 200] average loss generator vs. discrim.: 4.189685 vs. 0.078421 [39.329 seconds]
# Generator Checkpoint Saved [47 / 200]
# Discriminator Checkpoint Saved [47 / 200]
# No. of sample images stored: [49]
# Epoch [48 / 200], batch [127 / 246]: average loss generator vs. discrim.: 594.123768 vs. 8.956660 [20.776 seconds]
# No. of sample images stored: [49]
# Epoch [48 / 200] average loss generator vs. discrim.: 4.669725 vs. 0.275753 [39.934 seconds]
# Generator Checkpoint Saved [48 / 200]
# Discriminator Checkpoint Saved [48 / 200]
# No. of sample images stored: [50]
# Epoch [49 / 200], batch [127 / 246]: average loss generator vs. discrim.: 508.881003 vs. 13.459523 [20.547 seconds]
# No. of sample images stored: [50]
# Epoch [49 / 200] average loss generator vs. discrim.: 4.119818 vs. 0.190723 [38.971 seconds]
# Generator Checkpoint Saved [49 / 200]
# Discriminator Checkpoint Saved [49 / 200]
# No. of sample images stored: [51]
# Epoch [50 / 200], batch [127 / 246]: average loss generator vs. discrim.: 511.844189 vs. 35.776773 [20.821 seconds]
# No. of sample images stored: [51]
# Epoch [50 / 200] average loss generator vs. discrim.: 4.023639 vs. 0.223572 [39.476 seconds]
# Generator Checkpoint Saved [50 / 200]
# Discriminator Checkpoint Saved [50 / 200]
# No. of sample images stored: [52]
# Epoch [51 / 200], batch [127 / 246]: average loss generator vs. discrim.: 537.667285 vs. 21.704918 [21.134 seconds]
# No. of sample images stored: [52]
# Epoch [51 / 200] average loss generator vs. discrim.: 4.205827 vs. 0.128672 [39.699 seconds]
# Generator Checkpoint Saved [51 / 200]
# Discriminator Checkpoint Saved [51 / 200]
# No. of sample images stored: [53]
# Epoch [52 / 200], batch [127 / 246]: average loss generator vs. discrim.: 584.195200 vs. 28.940826 [20.557 seconds]
# No. of sample images stored: [53]
# Epoch [52 / 200] average loss generator vs. discrim.: 4.464318 vs. 0.245516 [39.496 seconds]
# Generator Checkpoint Saved [52 / 200]
# Discriminator Checkpoint Saved [52 / 200]
# No. of sample images stored: [54]
# Epoch [53 / 200], batch [127 / 246]: average loss generator vs. discrim.: 549.270233 vs. 17.294186 [20.538 seconds]
# No. of sample images stored: [54]
# Epoch [53 / 200] average loss generator vs. discrim.: 4.313527 vs. 0.107773 [39.345 seconds]
# Generator Checkpoint Saved [53 / 200]
# Discriminator Checkpoint Saved [53 / 200]
# No. of sample images stored: [55]
# Epoch [54 / 200], batch [127 / 246]: average loss generator vs. discrim.: 549.282953 vs. 39.463846 [20.781 seconds]
# No. of sample images stored: [55]
# Epoch [54 / 200] average loss generator vs. discrim.: 4.267106 vs. 0.203312 [39.699 seconds]
# Generator Checkpoint Saved [54 / 200]
# Discriminator Checkpoint Saved [54 / 200]
# No. of sample images stored: [56]
# Epoch [55 / 200], batch [127 / 246]: average loss generator vs. discrim.: 562.289462 vs. 28.752280 [20.962 seconds]
# No. of sample images stored: [56]
# Epoch [55 / 200] average loss generator vs. discrim.: 4.308317 vs. 0.175288 [39.753 seconds]
# Generator Checkpoint Saved [55 / 200]
# Discriminator Checkpoint Saved [55 / 200]
# No. of sample images stored: [57]
# Epoch [56 / 200], batch [127 / 246]: average loss generator vs. discrim.: 564.926906 vs. 8.005746 [20.695 seconds]
# No. of sample images stored: [57]
# Epoch [56 / 200] average loss generator vs. discrim.: 4.581126 vs. 0.056375 [39.418 seconds]
# Generator Checkpoint Saved [56 / 200]
# Discriminator Checkpoint Saved [56 / 200]
# No. of sample images stored: [58]
# Epoch [57 / 200], batch [127 / 246]: average loss generator vs. discrim.: 580.664857 vs. 53.993596 [20.629 seconds]
# No. of sample images stored: [58]
# Epoch [57 / 200] average loss generator vs. discrim.: 4.415462 vs. 0.275309 [39.296 seconds]
# Generator Checkpoint Saved [57 / 200]
# Discriminator Checkpoint Saved [57 / 200]
# No. of sample images stored: [59]
# Epoch [58 / 200], batch [127 / 246]: average loss generator vs. discrim.: 560.519175 vs. 8.807414 [20.337 seconds]
# No. of sample images stored: [59]
# Epoch [58 / 200] average loss generator vs. discrim.: 4.471867 vs. 0.184921 [39.505 seconds]
# Generator Checkpoint Saved [58 / 200]
# Discriminator Checkpoint Saved [58 / 200]
# No. of sample images stored: [60]
# Epoch [59 / 200], batch [127 / 246]: average loss generator vs. discrim.: 557.912713 vs. 13.697784 [20.753 seconds]
# No. of sample images stored: [60]
# Epoch [59 / 200] average loss generator vs. discrim.: 4.418914 vs. 0.079860 [39.718 seconds]
# Generator Checkpoint Saved [59 / 200]
# Discriminator Checkpoint Saved [59 / 200]
# No. of sample images stored: [61]
# Epoch [60 / 200], batch [127 / 246]: average loss generator vs. discrim.: 618.364052 vs. 40.499632 [21.105 seconds]
# No. of sample images stored: [61]
# Epoch [60 / 200] average loss generator vs. discrim.: 4.480482 vs. 0.339780 [39.994 seconds]
# Generator Checkpoint Saved [60 / 200]
# Discriminator Checkpoint Saved [60 / 200]
# No. of sample images stored: [62]
# Epoch [61 / 200], batch [127 / 246]: average loss generator vs. discrim.: 503.343482 vs. 19.424910 [21.007 seconds]
# No. of sample images stored: [62]
# Epoch [61 / 200] average loss generator vs. discrim.: 4.037538 vs. 0.115960 [39.182 seconds]
# Generator Checkpoint Saved [61 / 200]
# Discriminator Checkpoint Saved [61 / 200]
# No. of sample images stored: [63]
# Epoch [62 / 200], batch [127 / 246]: average loss generator vs. discrim.: 558.562055 vs. 7.587318 [21.233 seconds]
# No. of sample images stored: [63]
# Epoch [62 / 200] average loss generator vs. discrim.: 4.403319 vs. 0.210134 [40.613 seconds]
# Generator Checkpoint Saved [62 / 200]
# Discriminator Checkpoint Saved [62 / 200]
# No. of sample images stored: [64]
# Epoch [63 / 200], batch [127 / 246]: average loss generator vs. discrim.: 530.134352 vs. 15.081650 [20.834 seconds]
# No. of sample images stored: [64]
# Epoch [63 / 200] average loss generator vs. discrim.: 4.355821 vs. 0.095517 [40.177 seconds]
# Generator Checkpoint Saved [63 / 200]
# Discriminator Checkpoint Saved [63 / 200]
# No. of sample images stored: [65]
# Epoch [64 / 200], batch [127 / 246]: average loss generator vs. discrim.: 612.591063 vs. 12.124509 [21.15 seconds]
# No. of sample images stored: [65]
# Epoch [64 / 200] average loss generator vs. discrim.: 4.787782 vs. 0.177359 [39.984 seconds]
# Generator Checkpoint Saved [64 / 200]
# Discriminator Checkpoint Saved [64 / 200]
# No. of sample images stored: [66]
# Epoch [65 / 200], batch [127 / 246]: average loss generator vs. discrim.: 568.539414 vs. 8.301011 [21.051 seconds]
# No. of sample images stored: [66]
# Epoch [65 / 200] average loss generator vs. discrim.: 4.549545 vs. 0.050393 [40.039 seconds]
# Generator Checkpoint Saved [65 / 200]
# Discriminator Checkpoint Saved [65 / 200]
# No. of sample images stored: [67]
# Epoch [66 / 200], batch [127 / 246]: average loss generator vs. discrim.: 631.272724 vs. 33.305597 [21.696 seconds]
# No. of sample images stored: [67]
# Epoch [66 / 200] average loss generator vs. discrim.: 4.750369 vs. 0.251579 [40.799 seconds]
# Generator Checkpoint Saved [66 / 200]
# Discriminator Checkpoint Saved [66 / 200]
# No. of sample images stored: [68]
# Epoch [67 / 200], batch [127 / 246]: average loss generator vs. discrim.: 539.024095 vs. 12.863249 [21.071 seconds]
# No. of sample images stored: [68]
# Epoch [67 / 200] average loss generator vs. discrim.: 4.410400 vs. 0.073702 [40.196 seconds]
# Generator Checkpoint Saved [67 / 200]
# Discriminator Checkpoint Saved [67 / 200]
# No. of sample images stored: [69]
# Epoch [68 / 200], batch [127 / 246]: average loss generator vs. discrim.: 608.617595 vs. 4.053948 [21.32 seconds]
# No. of sample images stored: [69]
# Epoch [68 / 200] average loss generator vs. discrim.: 4.855157 vs. 0.030150 [40.17 seconds]
# Generator Checkpoint Saved [68 / 200]
# Discriminator Checkpoint Saved [68 / 200]
# No. of sample images stored: [70]
# Epoch [69 / 200], batch [127 / 246]: average loss generator vs. discrim.: 658.811337 vs. 3.353230 [20.989 seconds]
# No. of sample images stored: [70]
# Epoch [69 / 200] average loss generator vs. discrim.: 4.979764 vs. 0.255138 [39.891 seconds]
# Generator Checkpoint Saved [69 / 200]
# Discriminator Checkpoint Saved [69 / 200]
# No. of sample images stored: [71]
# Epoch [70 / 200], batch [127 / 246]: average loss generator vs. discrim.: 576.664449 vs. 19.171002 [20.426 seconds]
# No. of sample images stored: [71]
# Epoch [70 / 200] average loss generator vs. discrim.: 4.601052 vs. 0.111727 [39.648 seconds]
# Generator Checkpoint Saved [70 / 200]
# Discriminator Checkpoint Saved [70 / 200]
# No. of sample images stored: [72]
# Epoch [71 / 200], batch [127 / 246]: average loss generator vs. discrim.: 608.157900 vs. 5.796987 [21.245 seconds]
# No. of sample images stored: [72]
# Epoch [71 / 200] average loss generator vs. discrim.: 4.864572 vs. 0.165925 [39.776 seconds]
# Generator Checkpoint Saved [71 / 200]
# Discriminator Checkpoint Saved [71 / 200]
# No. of sample images stored: [73]
# Epoch [72 / 200], batch [127 / 246]: average loss generator vs. discrim.: 551.494226 vs. 31.003705 [20.616 seconds]
# No. of sample images stored: [73]
# Epoch [72 / 200] average loss generator vs. discrim.: 4.434344 vs. 0.203989 [39.294 seconds]
# Generator Checkpoint Saved [72 / 200]
# Discriminator Checkpoint Saved [72 / 200]
# No. of sample images stored: [74]
# Epoch [73 / 200], batch [127 / 246]: average loss generator vs. discrim.: 580.847128 vs. 7.834088 [21.298 seconds]
# No. of sample images stored: [74]
# Epoch [73 / 200] average loss generator vs. discrim.: 4.571289 vs. 0.136076 [39.983 seconds]
# Generator Checkpoint Saved [73 / 200]
# Discriminator Checkpoint Saved [73 / 200]
# No. of sample images stored: [75]
# Epoch [74 / 200], batch [127 / 246]: average loss generator vs. discrim.: 603.869102 vs. 5.313035 [21.039 seconds]
# No. of sample images stored: [75]
# Epoch [74 / 200] average loss generator vs. discrim.: 4.814474 vs. 0.036350 [39.845 seconds]
# Generator Checkpoint Saved [74 / 200]
# Discriminator Checkpoint Saved [74 / 200]
# No. of sample images stored: [76]
# Epoch [75 / 200], batch [127 / 246]: average loss generator vs. discrim.: 643.506568 vs. 3.138437 [21.126 seconds]
# No. of sample images stored: [76]
# Epoch [75 / 200] average loss generator vs. discrim.: 5.182481 vs. 0.025534 [39.646 seconds]
# Generator Checkpoint Saved [75 / 200]
# Discriminator Checkpoint Saved [75 / 200]
# No. of sample images stored: [77]
# Epoch [76 / 200], batch [127 / 246]: average loss generator vs. discrim.: 679.148752 vs. 2.532312 [20.989 seconds]
# No. of sample images stored: [77]
# Epoch [76 / 200] average loss generator vs. discrim.: 5.200501 vs. 0.310319 [39.601 seconds]
# Generator Checkpoint Saved [76 / 200]
# Discriminator Checkpoint Saved [76 / 200]
# No. of sample images stored: [78]
# Epoch [77 / 200], batch [127 / 246]: average loss generator vs. discrim.: 559.780054 vs. 30.529142 [20.728 seconds]
# No. of sample images stored: [78]
# Epoch [77 / 200] average loss generator vs. discrim.: 4.349388 vs. 0.196978 [39.671 seconds]
# Generator Checkpoint Saved [77 / 200]
# Discriminator Checkpoint Saved [77 / 200]
# No. of sample images stored: [79]
# Epoch [78 / 200], batch [127 / 246]: average loss generator vs. discrim.: 570.812975 vs. 16.189622 [20.478 seconds]
# No. of sample images stored: [79]
# Epoch [78 / 200] average loss generator vs. discrim.: 4.573464 vs. 0.090431 [38.876 seconds]
# Generator Checkpoint Saved [78 / 200]
# Discriminator Checkpoint Saved [78 / 200]
# No. of sample images stored: [80]
# Epoch [79 / 200], batch [127 / 246]: average loss generator vs. discrim.: 622.519740 vs. 3.967427 [21.127 seconds]
# No. of sample images stored: [80]
# Epoch [79 / 200] average loss generator vs. discrim.: 4.781305 vs. 0.171504 [40.495 seconds]
# Generator Checkpoint Saved [79 / 200]
# Discriminator Checkpoint Saved [79 / 200]
# No. of sample images stored: [81]
# Epoch [80 / 200], batch [127 / 246]: average loss generator vs. discrim.: 594.112726 vs. 13.801763 [21.649 seconds]
# No. of sample images stored: [81]
# Epoch [80 / 200] average loss generator vs. discrim.: 4.741810 vs. 0.072918 [41.079 seconds]
# Generator Checkpoint Saved [80 / 200]
# Discriminator Checkpoint Saved [80 / 200]
# No. of sample images stored: [82]
# Epoch [81 / 200], batch [127 / 246]: average loss generator vs. discrim.: 643.629101 vs. 8.314115 [21.511 seconds]
# No. of sample images stored: [82]
# Epoch [81 / 200] average loss generator vs. discrim.: 5.026118 vs. 0.149940 [40.599 seconds]
# Generator Checkpoint Saved [81 / 200]
# Discriminator Checkpoint Saved [81 / 200]
# No. of sample images stored: [83]
# Epoch [82 / 200], batch [127 / 246]: average loss generator vs. discrim.: 615.468721 vs. 16.296513 [21.245 seconds]
# No. of sample images stored: [83]
# Epoch [82 / 200] average loss generator vs. discrim.: 4.852293 vs. 0.088477 [40.341 seconds]
# Generator Checkpoint Saved [82 / 200]
# Discriminator Checkpoint Saved [82 / 200]
# No. of sample images stored: [84]
# Epoch [83 / 200], batch [127 / 246]: average loss generator vs. discrim.: 644.661694 vs. 3.299511 [20.986 seconds]
# No. of sample images stored: [84]
# Epoch [83 / 200] average loss generator vs. discrim.: 5.056015 vs. 0.142142 [39.818 seconds]
# Generator Checkpoint Saved [83 / 200]
# Discriminator Checkpoint Saved [83 / 200]
# No. of sample images stored: [85]
# Epoch [84 / 200], batch [127 / 246]: average loss generator vs. discrim.: 598.433911 vs. 12.631731 [20.831 seconds]
# No. of sample images stored: [85]
# Epoch [84 / 200] average loss generator vs. discrim.: 4.857027 vs. 0.201057 [40.115 seconds]
# Generator Checkpoint Saved [84 / 200]
# Discriminator Checkpoint Saved [84 / 200]
# No. of sample images stored: [86]
# Epoch [85 / 200], batch [127 / 246]: average loss generator vs. discrim.: 567.668355 vs. 10.338607 [20.975 seconds]
# No. of sample images stored: [86]
# Epoch [85 / 200] average loss generator vs. discrim.: 4.648361 vs. 0.064183 [39.618 seconds]
# Generator Checkpoint Saved [85 / 200]
# Discriminator Checkpoint Saved [85 / 200]
# No. of sample images stored: [87]
# Epoch [86 / 200], batch [127 / 246]: average loss generator vs. discrim.: 646.071047 vs. 3.170013 [21.219 seconds]
# No. of sample images stored: [87]
# Epoch [86 / 200] average loss generator vs. discrim.: 5.074010 vs. 0.147777 [39.798 seconds]
# Generator Checkpoint Saved [86 / 200]
# Discriminator Checkpoint Saved [86 / 200]
# No. of sample images stored: [88]
# Epoch [87 / 200], batch [127 / 246]: average loss generator vs. discrim.: 592.497806 vs. 15.128322 [21.548 seconds]
# No. of sample images stored: [88]
# Epoch [87 / 200] average loss generator vs. discrim.: 4.740052 vs. 0.112513 [40.876 seconds]
# Generator Checkpoint Saved [87 / 200]
# Discriminator Checkpoint Saved [87 / 200]
# No. of sample images stored: [89]
# Epoch [88 / 200], batch [127 / 246]: average loss generator vs. discrim.: 635.585464 vs. 11.001209 [21.293 seconds]
# No. of sample images stored: [89]
# Epoch [88 / 200] average loss generator vs. discrim.: 5.032037 vs. 0.122904 [40.11 seconds]
# Generator Checkpoint Saved [88 / 200]
# Discriminator Checkpoint Saved [88 / 200]
# No. of sample images stored: [90]
# Epoch [89 / 200], batch [127 / 246]: average loss generator vs. discrim.: 563.100077 vs. 25.806767 [21.4 seconds]
# No. of sample images stored: [90]
# Epoch [89 / 200] average loss generator vs. discrim.: 4.478226 vs. 0.162402 [40.144 seconds]
# Generator Checkpoint Saved [89 / 200]
# Discriminator Checkpoint Saved [89 / 200]
# No. of sample images stored: [91]
# Epoch [90 / 200], batch [127 / 246]: average loss generator vs. discrim.: 599.260439 vs. 4.646972 [21.364 seconds]
# No. of sample images stored: [91]
# Epoch [90 / 200] average loss generator vs. discrim.: 4.863356 vs. 0.034211 [40.105 seconds]
# Generator Checkpoint Saved [90 / 200]
# Discriminator Checkpoint Saved [90 / 200]
# No. of sample images stored: [92]
# Epoch [91 / 200], batch [127 / 246]: average loss generator vs. discrim.: 685.211656 vs. 2.276300 [21.129 seconds]
# No. of sample images stored: [92]
# Epoch [91 / 200] average loss generator vs. discrim.: 5.551340 vs. 0.149297 [40.126 seconds]
# Generator Checkpoint Saved [91 / 200]
# Discriminator Checkpoint Saved [91 / 200]
# No. of sample images stored: [93]
# Epoch [92 / 200], batch [127 / 246]: average loss generator vs. discrim.: 648.751779 vs. 12.555770 [21.141 seconds]
# No. of sample images stored: [93]
# Epoch [92 / 200] average loss generator vs. discrim.: 4.955200 vs. 0.171111 [39.888 seconds]
# Generator Checkpoint Saved [92 / 200]
# Discriminator Checkpoint Saved [92 / 200]
# No. of sample images stored: [94]
# Epoch [93 / 200], batch [127 / 246]: average loss generator vs. discrim.: 611.044517 vs. 10.052863 [20.879 seconds]
# No. of sample images stored: [94]
# Epoch [93 / 200] average loss generator vs. discrim.: 4.991559 vs. 0.054253 [39.684 seconds]
# Generator Checkpoint Saved [93 / 200]
# Discriminator Checkpoint Saved [93 / 200]
# No. of sample images stored: [95]
# Epoch [94 / 200], batch [127 / 246]: average loss generator vs. discrim.: 666.939355 vs. 2.752951 [20.855 seconds]
# No. of sample images stored: [95]
# Epoch [94 / 200] average loss generator vs. discrim.: 5.361030 vs. 0.021539 [39.458 seconds]
# Generator Checkpoint Saved [94 / 200]
# Discriminator Checkpoint Saved [94 / 200]
# No. of sample images stored: [96]
# Epoch [95 / 200], batch [127 / 246]: average loss generator vs. discrim.: 752.038582 vs. 14.114391 [20.961 seconds]
# No. of sample images stored: [96]
# Epoch [95 / 200] average loss generator vs. discrim.: 5.720190 vs. 0.181957 [39.327 seconds]
# Generator Checkpoint Saved [95 / 200]
# Discriminator Checkpoint Saved [95 / 200]
# No. of sample images stored: [97]
# Epoch [96 / 200], batch [127 / 246]: average loss generator vs. discrim.: 629.482671 vs. 7.100894 [21.476 seconds]
# No. of sample images stored: [97]
# Epoch [96 / 200] average loss generator vs. discrim.: 4.873576 vs. 0.198080 [41.049 seconds]
# Generator Checkpoint Saved [96 / 200]
# Discriminator Checkpoint Saved [96 / 200]
# No. of sample images stored: [98]
# Epoch [97 / 200], batch [127 / 246]: average loss generator vs. discrim.: 584.491498 vs. 15.745322 [21.921 seconds]
# No. of sample images stored: [98]
# Epoch [97 / 200] average loss generator vs. discrim.: 4.705081 vs. 0.088815 [40.891 seconds]
# Generator Checkpoint Saved [97 / 200]
# Discriminator Checkpoint Saved [97 / 200]
# No. of sample images stored: [99]
# Epoch [98 / 200], batch [127 / 246]: average loss generator vs. discrim.: 635.463151 vs. 4.947329 [21.389 seconds]
# No. of sample images stored: [99]
# Epoch [98 / 200] average loss generator vs. discrim.: 5.042497 vs. 0.043665 [40.287 seconds]
# Generator Checkpoint Saved [98 / 200]
# Discriminator Checkpoint Saved [98 / 200]
# No. of sample images stored: [100]
# Epoch [99 / 200], batch [127 / 246]: average loss generator vs. discrim.: 664.705076 vs. 2.960782 [20.785 seconds]
# No. of sample images stored: [100]
# Epoch [99 / 200] average loss generator vs. discrim.: 5.259927 vs. 0.193603 [39.251 seconds]
# Generator Checkpoint Saved [99 / 200]
# Discriminator Checkpoint Saved [99 / 200]
# No. of sample images stored: [101]
# Epoch [100 / 200], batch [127 / 246]: average loss generator vs. discrim.: 612.278964 vs. 7.117398 [21.523 seconds]
# No. of sample images stored: [101]
# Epoch [100 / 200] average loss generator vs. discrim.: 4.937047 vs. 0.099406 [40.595 seconds]
# Generator Checkpoint Saved [100 / 200]
# Discriminator Checkpoint Saved [100 / 200]
# No. of sample images stored: [102]
# Epoch [101 / 200], batch [127 / 246]: average loss generator vs. discrim.: 622.128560 vs. 9.726665 [21.679 seconds]
# No. of sample images stored: [102]
# Epoch [101 / 200] average loss generator vs. discrim.: 4.982145 vs. 0.057140 [41.093 seconds]
# Generator Checkpoint Saved [101 / 200]
# Discriminator Checkpoint Saved [101 / 200]
# No. of sample images stored: [103]
# Epoch [102 / 200], batch [127 / 246]: average loss generator vs. discrim.: 665.826908 vs. 2.952542 [21.756 seconds]
# No. of sample images stored: [103]
# Epoch [102 / 200] average loss generator vs. discrim.: 5.304267 vs. 0.021011 [41.052 seconds]
# Generator Checkpoint Saved [102 / 200]
# Discriminator Checkpoint Saved [102 / 200]
# No. of sample images stored: [104]
# Epoch [103 / 200], batch [127 / 246]: average loss generator vs. discrim.: 704.492181 vs. 1.895317 [21.441 seconds]
# No. of sample images stored: [104]
# Epoch [103 / 200] average loss generator vs. discrim.: 5.504909 vs. 0.176366 [40.305 seconds]
# Generator Checkpoint Saved [103 / 200]
# Discriminator Checkpoint Saved [103 / 200]
# No. of sample images stored: [105]
# Epoch [104 / 200], batch [127 / 246]: average loss generator vs. discrim.: 617.957570 vs. 24.053849 [22.043 seconds]
# No. of sample images stored: [105]
# Epoch [104 / 200] average loss generator vs. discrim.: 4.870956 vs. 0.130493 [41.123 seconds]
# Generator Checkpoint Saved [104 / 200]
# Discriminator Checkpoint Saved [104 / 200]
# No. of sample images stored: [106]
# Epoch [105 / 200], batch [127 / 246]: average loss generator vs. discrim.: 655.777662 vs. 26.956438 [21.979 seconds]
# No. of sample images stored: [106]
# Epoch [105 / 200] average loss generator vs. discrim.: 4.839627 vs. 0.218444 [41.175 seconds]
# Generator Checkpoint Saved [105 / 200]
# Discriminator Checkpoint Saved [105 / 200]
# No. of sample images stored: [107]
# Epoch [106 / 200], batch [127 / 246]: average loss generator vs. discrim.: 599.038423 vs. 10.463176 [21.717 seconds]
# No. of sample images stored: [107]
# Epoch [106 / 200] average loss generator vs. discrim.: 4.864710 vs. 0.065016 [41.101 seconds]
# Generator Checkpoint Saved [106 / 200]
# Discriminator Checkpoint Saved [106 / 200]
# No. of sample images stored: [108]
# Epoch [107 / 200], batch [127 / 246]: average loss generator vs. discrim.: 642.766804 vs. 25.530118 [21.797 seconds]
# No. of sample images stored: [108]
# Epoch [107 / 200] average loss generator vs. discrim.: 4.966779 vs. 0.151346 [40.559 seconds]
# Generator Checkpoint Saved [107 / 200]
# Discriminator Checkpoint Saved [107 / 200]
# No. of sample images stored: [109]
# Epoch [108 / 200], batch [127 / 246]: average loss generator vs. discrim.: 645.061304 vs. 3.823284 [21.54 seconds]
# No. of sample images stored: [109]
# Epoch [108 / 200] average loss generator vs. discrim.: 5.106220 vs. 0.027410 [40.526 seconds]
# Generator Checkpoint Saved [108 / 200]
# Discriminator Checkpoint Saved [108 / 200]
# No. of sample images stored: [110]
# Epoch [109 / 200], batch [127 / 246]: average loss generator vs. discrim.: 680.399377 vs. 2.419368 [21.541 seconds]
# No. of sample images stored: [110]
# Epoch [109 / 200] average loss generator vs. discrim.: 5.509807 vs. 0.018748 [39.747 seconds]
# Generator Checkpoint Saved [109 / 200]
# Discriminator Checkpoint Saved [109 / 200]
# No. of sample images stored: [111]
# Epoch [110 / 200], batch [127 / 246]: average loss generator vs. discrim.: 661.808323 vs. 38.105390 [21.37 seconds]
# No. of sample images stored: [111]
# Epoch [110 / 200] average loss generator vs. discrim.: 5.111768 vs. 0.226888 [40.239 seconds]
# Generator Checkpoint Saved [110 / 200]
# Discriminator Checkpoint Saved [110 / 200]
# No. of sample images stored: [112]
# Epoch [111 / 200], batch [127 / 246]: average loss generator vs. discrim.: 624.121234 vs. 15.876394 [20.773 seconds]
# No. of sample images stored: [112]
# Epoch [111 / 200] average loss generator vs. discrim.: 5.009125 vs. 0.093789 [39.421 seconds]
# Generator Checkpoint Saved [111 / 200]
# Discriminator Checkpoint Saved [111 / 200]
# No. of sample images stored: [113]
# Epoch [112 / 200], batch [127 / 246]: average loss generator vs. discrim.: 677.017959 vs. 3.212942 [21.447 seconds]
# No. of sample images stored: [113]
# Epoch [112 / 200] average loss generator vs. discrim.: 5.414096 vs. 0.021278 [40.279 seconds]
# Generator Checkpoint Saved [112 / 200]
# Discriminator Checkpoint Saved [112 / 200]
# No. of sample images stored: [114]
# Epoch [113 / 200], batch [127 / 246]: average loss generator vs. discrim.: 705.006497 vs. 11.298905 [21.434 seconds]
# No. of sample images stored: [114]
# Epoch [113 / 200] average loss generator vs. discrim.: 5.550171 vs. 0.061753 [40.432 seconds]
# Generator Checkpoint Saved [113 / 200]
# Discriminator Checkpoint Saved [113 / 200]
# No. of sample images stored: [115]
# Epoch [114 / 200], batch [127 / 246]: average loss generator vs. discrim.: 769.280675 vs. 1.589459 [21.437 seconds]
# No. of sample images stored: [115]
# Epoch [114 / 200] average loss generator vs. discrim.: 6.030138 vs. 0.012636 [40.74 seconds]
# Generator Checkpoint Saved [114 / 200]
# Discriminator Checkpoint Saved [114 / 200]
# No. of sample images stored: [116]
# Epoch [115 / 200], batch [127 / 246]: average loss generator vs. discrim.: 774.383973 vs. 1.273891 [21.332 seconds]
# No. of sample images stored: [116]
# Epoch [115 / 200] average loss generator vs. discrim.: 6.121210 vs. 0.191017 [40.468 seconds]
# Generator Checkpoint Saved [115 / 200]
# Discriminator Checkpoint Saved [115 / 200]
# No. of sample images stored: [117]
# Epoch [116 / 200], batch [127 / 246]: average loss generator vs. discrim.: 658.074202 vs. 38.703799 [21.533 seconds]
# No. of sample images stored: [117]
# Epoch [116 / 200] average loss generator vs. discrim.: 5.070883 vs. 0.232365 [40.345 seconds]
# Generator Checkpoint Saved [116 / 200]
# Discriminator Checkpoint Saved [116 / 200]
# No. of sample images stored: [118]
# Epoch [117 / 200], batch [127 / 246]: average loss generator vs. discrim.: 634.493360 vs. 10.062271 [21.447 seconds]
# No. of sample images stored: [118]
# Epoch [117 / 200] average loss generator vs. discrim.: 5.095332 vs. 0.058692 [40.822 seconds]
# Generator Checkpoint Saved [117 / 200]
# Discriminator Checkpoint Saved [117 / 200]
# No. of sample images stored: [119]
# Epoch [118 / 200], batch [127 / 246]: average loss generator vs. discrim.: 679.346493 vs. 3.706639 [21.391 seconds]
# No. of sample images stored: [119]
# Epoch [118 / 200] average loss generator vs. discrim.: 5.491265 vs. 0.022658 [40.675 seconds]
# Generator Checkpoint Saved [118 / 200]
# Discriminator Checkpoint Saved [118 / 200]
# No. of sample images stored: [120]
# Epoch [119 / 200], batch [127 / 246]: average loss generator vs. discrim.: 726.268765 vs. 2.066010 [20.923 seconds]
# No. of sample images stored: [120]
# Epoch [119 / 200] average loss generator vs. discrim.: 5.792098 vs. 0.014230 [39.713 seconds]
# Generator Checkpoint Saved [119 / 200]
# Discriminator Checkpoint Saved [119 / 200]
# No. of sample images stored: [121]
# Epoch [120 / 200], batch [127 / 246]: average loss generator vs. discrim.: 769.935820 vs. 1.426986 [20.896 seconds]
# No. of sample images stored: [121]
# Epoch [120 / 200] average loss generator vs. discrim.: 5.829762 vs. 0.213571 [39.627 seconds]
# Generator Checkpoint Saved [120 / 200]
# Discriminator Checkpoint Saved [120 / 200]
# No. of sample images stored: [122]
# Epoch [121 / 200], batch [127 / 246]: average loss generator vs. discrim.: 633.212428 vs. 22.109192 [20.822 seconds]
# No. of sample images stored: [122]
# Epoch [121 / 200] average loss generator vs. discrim.: 5.031642 vs. 0.120001 [39.663 seconds]
# Generator Checkpoint Saved [121 / 200]
# Discriminator Checkpoint Saved [121 / 200]
# No. of sample images stored: [123]
# Epoch [122 / 200], batch [127 / 246]: average loss generator vs. discrim.: 659.581737 vs. 26.043535 [21.006 seconds]
# No. of sample images stored: [123]
# Epoch [122 / 200] average loss generator vs. discrim.: 5.149189 vs. 0.181853 [39.382 seconds]
# Generator Checkpoint Saved [122 / 200]
# Discriminator Checkpoint Saved [122 / 200]
# No. of sample images stored: [124]
# Epoch [123 / 200], batch [127 / 246]: average loss generator vs. discrim.: 668.989902 vs. 5.072219 [21.068 seconds]
# No. of sample images stored: [124]
# Epoch [123 / 200] average loss generator vs. discrim.: 5.309524 vs. 0.032987 [39.625 seconds]
# Generator Checkpoint Saved [123 / 200]
# Discriminator Checkpoint Saved [123 / 200]
# No. of sample images stored: [125]
# Epoch [124 / 200], batch [127 / 246]: average loss generator vs. discrim.: 707.815816 vs. 2.016846 [21.03 seconds]
# No. of sample images stored: [125]
# Epoch [124 / 200] average loss generator vs. discrim.: 5.568467 vs. 0.020724 [39.246 seconds]
# Generator Checkpoint Saved [124 / 200]
# Discriminator Checkpoint Saved [124 / 200]
# No. of sample images stored: [126]
# Epoch [125 / 200], batch [127 / 246]: average loss generator vs. discrim.: 762.311077 vs. 1.676735 [21.228 seconds]
# No. of sample images stored: [126]
# Epoch [125 / 200] average loss generator vs. discrim.: 5.759638 vs. 0.189027 [39.409 seconds]
# Generator Checkpoint Saved [125 / 200]
# Discriminator Checkpoint Saved [125 / 200]
# No. of sample images stored: [127]
# Epoch [126 / 200], batch [127 / 246]: average loss generator vs. discrim.: 648.642490 vs. 12.858327 [20.987 seconds]
# No. of sample images stored: [127]
# Epoch [126 / 200] average loss generator vs. discrim.: 5.076809 vs. 0.086339 [39.391 seconds]
# Generator Checkpoint Saved [126 / 200]
# Discriminator Checkpoint Saved [126 / 200]
# No. of sample images stored: [128]
# Epoch [127 / 200], batch [127 / 246]: average loss generator vs. discrim.: 664.861378 vs. 19.439301 [20.843 seconds]
# No. of sample images stored: [128]
# Epoch [127 / 200] average loss generator vs. discrim.: 5.113465 vs. 0.166010 [39.431 seconds]
# Generator Checkpoint Saved [127 / 200]
# Discriminator Checkpoint Saved [127 / 200]
# No. of sample images stored: [129]
# Epoch [128 / 200], batch [127 / 246]: average loss generator vs. discrim.: 619.864424 vs. 7.104753 [20.916 seconds]
# No. of sample images stored: [129]
# Epoch [128 / 200] average loss generator vs. discrim.: 4.997970 vs. 0.045438 [39.666 seconds]
# Generator Checkpoint Saved [128 / 200]
# Discriminator Checkpoint Saved [128 / 200]
# No. of sample images stored: [130]
# Epoch [129 / 200], batch [127 / 246]: average loss generator vs. discrim.: 658.373830 vs. 2.998764 [20.798 seconds]
# No. of sample images stored: [130]
# Epoch [129 / 200] average loss generator vs. discrim.: 5.253294 vs. 0.022712 [39.984 seconds]
# Generator Checkpoint Saved [129 / 200]
# Discriminator Checkpoint Saved [129 / 200]
# No. of sample images stored: [131]
# Epoch [130 / 200], batch [127 / 246]: average loss generator vs. discrim.: 690.534361 vs. 41.182863 [21.197 seconds]
# No. of sample images stored: [131]
# Epoch [130 / 200] average loss generator vs. discrim.: 5.108184 vs. 0.254947 [39.992 seconds]
# Generator Checkpoint Saved [130 / 200]
# Discriminator Checkpoint Saved [130 / 200]
# No. of sample images stored: [132]
# Epoch [131 / 200], batch [127 / 246]: average loss generator vs. discrim.: 626.679248 vs. 6.473369 [21.178 seconds]
# No. of sample images stored: [132]
# Epoch [131 / 200] average loss generator vs. discrim.: 5.099959 vs. 0.039214 [39.627 seconds]
# Generator Checkpoint Saved [131 / 200]
# Discriminator Checkpoint Saved [131 / 200]
# No. of sample images stored: [133]
# Epoch [132 / 200], batch [127 / 246]: average loss generator vs. discrim.: 640.645633 vs. 25.437917 [21.369 seconds]
# No. of sample images stored: [133]
# Epoch [132 / 200] average loss generator vs. discrim.: 5.127195 vs. 0.153617 [40.417 seconds]
# Generator Checkpoint Saved [132 / 200]
# Discriminator Checkpoint Saved [132 / 200]
# No. of sample images stored: [134]
# Epoch [133 / 200], batch [127 / 246]: average loss generator vs. discrim.: 666.188614 vs. 5.761311 [21.057 seconds]
# No. of sample images stored: [134]
# Epoch [133 / 200] average loss generator vs. discrim.: 5.362825 vs. 0.033479 [39.884 seconds]
# Generator Checkpoint Saved [133 / 200]
# Discriminator Checkpoint Saved [133 / 200]
# No. of sample images stored: [135]
# Epoch [134 / 200], batch [127 / 246]: average loss generator vs. discrim.: 663.404921 vs. 19.644696 [21.217 seconds]
# No. of sample images stored: [135]
# Epoch [134 / 200] average loss generator vs. discrim.: 5.260267 vs. 0.104113 [39.999 seconds]
# Generator Checkpoint Saved [134 / 200]
# Discriminator Checkpoint Saved [134 / 200]
# ...
# Discriminator Checkpoint Saved [156 / 200]
# No. of sample images stored: [158]
# Epoch [157 / 200], batch [127 / 246]: average loss generator vs. discrim.: 775.330217 vs. 1.971466 [21.061 seconds]
# No. of sample images stored: [158]
# Epoch [157 / 200] average loss generator vs. discrim.: 6.110110 vs. 0.013771 [40.923 seconds]
# Generator Checkpoint Saved [157 / 200]
# Discriminator Checkpoint Saved [157 / 200]
# No. of sample images stored: [159]
# Epoch [158 / 200], batch [127 / 246]: average loss generator vs. discrim.: 785.490071 vs. 1.244075 [21.405 seconds]
# No. of sample images stored: [159]
# Epoch [158 / 200] average loss generator vs. discrim.: 6.197935 vs. 0.448734 [39.341 seconds]
# Generator Checkpoint Saved [158 / 200]
# Discriminator Checkpoint Saved [158 / 200]
# No. of sample images stored: [160]
# Epoch [159 / 200], batch [127 / 246]: average loss generator vs. discrim.: 664.953151 vs. 37.649633 [20.91 seconds]
# No. of sample images stored: [160]
# Epoch [159 / 200] average loss generator vs. discrim.: 5.185319 vs. 0.223654 [39.198 seconds]
# Generator Checkpoint Saved [159 / 200]
# Discriminator Checkpoint Saved [159 / 200]
# No. of sample images stored: [161]
# Epoch [160 / 200], batch [127 / 246]: average loss generator vs. discrim.: 667.313319 vs. 5.562253 [21.643 seconds]
# No. of sample images stored: [161]
# Epoch [160 / 200] average loss generator vs. discrim.: 5.314841 vs. 0.038764 [40.558 seconds]
# Generator Checkpoint Saved [160 / 200]
# Discriminator Checkpoint Saved [160 / 200]
# No. of sample images stored: [162]
# Epoch [161 / 200], batch [127 / 246]: average loss generator vs. discrim.: 693.877159 vs. 15.955607 [21.107 seconds]
# No. of sample images stored: [162]
# Epoch [161 / 200] average loss generator vs. discrim.: 5.424927 vs. 0.084181 [40.071 seconds]
# Generator Checkpoint Saved [161 / 200]
# Discriminator Checkpoint Saved [161 / 200]
# No. of sample images stored: [163]
# Epoch [162 / 200], batch [127 / 246]: average loss generator vs. discrim.: 732.587299 vs. 2.480601 [21.566 seconds]
# No. of sample images stored: [163]
# Epoch [162 / 200] average loss generator vs. discrim.: 5.745535 vs. 0.019256 [40.74 seconds]
# Generator Checkpoint Saved [162 / 200]
# Discriminator Checkpoint Saved [162 / 200]
# No. of sample images stored: [164]
# Epoch [163 / 200], batch [127 / 246]: average loss generator vs. discrim.: 768.404369 vs. 1.440054 [20.829 seconds]
# No. of sample images stored: [164]
# Epoch [163 / 200] average loss generator vs. discrim.: 6.000109 vs. 0.129319 [40.065 seconds]
# Generator Checkpoint Saved [163 / 200]
# Discriminator Checkpoint Saved [163 / 200]
# No. of sample images stored: [165]
# Epoch [164 / 200], batch [127 / 246]: average loss generator vs. discrim.: 692.080048 vs. 8.355652 [21.724 seconds]
# No. of sample images stored: [165]
# Epoch [164 / 200] average loss generator vs. discrim.: 5.441113 vs. 0.052365 [41.04 seconds]
# Generator Checkpoint Saved [164 / 200]
# Discriminator Checkpoint Saved [164 / 200]
# No. of sample images stored: [166]
# Epoch [165 / 200], batch [127 / 246]: average loss generator vs. discrim.: 701.280737 vs. 11.737366 [21.184 seconds]
# No. of sample images stored: [166]
# Epoch [165 / 200] average loss generator vs. discrim.: 5.499192 vs. 0.061600 [40.713 seconds]
# Generator Checkpoint Saved [165 / 200]
# Discriminator Checkpoint Saved [165 / 200]
# No. of sample images stored: [167]
# Epoch [166 / 200], batch [127 / 246]: average loss generator vs. discrim.: 737.137246 vs. 2.077376 [21.413 seconds]
# No. of sample images stored: [167]
# Epoch [166 / 200] average loss generator vs. discrim.: 5.839514 vs. 0.015668 [40.575 seconds]
# Generator Checkpoint Saved [166 / 200]
# Discriminator Checkpoint Saved [166 / 200]
# No. of sample images stored: [168]
# Epoch [167 / 200], batch [127 / 246]: average loss generator vs. discrim.: 710.312970 vs. 33.375174 [21.497 seconds]
# No. of sample images stored: [168]
# Epoch [167 / 200] average loss generator vs. discrim.: 5.578820 vs. 0.154223 [40.766 seconds]
# Generator Checkpoint Saved [167 / 200]
# Discriminator Checkpoint Saved [167 / 200]
# No. of sample images stored: [169]
# Epoch [168 / 200], batch [127 / 246]: average loss generator vs. discrim.: 750.725199 vs. 2.574618 [21.854 seconds]
# No. of sample images stored: [169]
# Epoch [168 / 200] average loss generator vs. discrim.: 5.977020 vs. 0.017071 [40.892 seconds]
# Generator Checkpoint Saved [168 / 200]
# Discriminator Checkpoint Saved [168 / 200]
# No. of sample images stored: [170]
# Epoch [169 / 200], batch [127 / 246]: average loss generator vs. discrim.: 788.676856 vs. 1.208354 [21.394 seconds]
# No. of sample images stored: [170]
# Epoch [169 / 200] average loss generator vs. discrim.: 6.237442 vs. 0.009041 [40.4 seconds]
# Generator Checkpoint Saved [169 / 200]
# Discriminator Checkpoint Saved [169 / 200]
# No. of sample images stored: [171]
# Epoch [170 / 200], batch [127 / 246]: average loss generator vs. discrim.: 815.961763 vs. 0.892386 [21.923 seconds]
# No. of sample images stored: [171]
# Epoch [170 / 200] average loss generator vs. discrim.: 6.525182 vs. 0.006940 [40.654 seconds]
# Generator Checkpoint Saved [170 / 200]
# Discriminator Checkpoint Saved [170 / 200]
# No. of sample images stored: [172]
# Epoch [171 / 200], batch [127 / 246]: average loss generator vs. discrim.: 846.059908 vs. 0.827838 [22.347 seconds]
# No. of sample images stored: [172]
# Epoch [171 / 200] average loss generator vs. discrim.: 6.643275 vs. 0.006203 [41.669 seconds]
# Generator Checkpoint Saved [171 / 200]
# Discriminator Checkpoint Saved [171 / 200]
# No. of sample images stored: [173]
# Epoch [172 / 200], batch [127 / 246]: average loss generator vs. discrim.: 762.028515 vs. 46.088123 [21.916 seconds]
# No. of sample images stored: [173]
# Epoch [172 / 200] average loss generator vs. discrim.: 5.786669 vs. 0.223975 [41.19 seconds]
# Generator Checkpoint Saved [172 / 200]
# Discriminator Checkpoint Saved [172 / 200]
# No. of sample images stored: [174]
# Epoch [173 / 200], batch [127 / 246]: average loss generator vs. discrim.: 698.059697 vs. 15.409144 [21.785 seconds]
# No. of sample images stored: [174]
# Epoch [173 / 200] average loss generator vs. discrim.: 5.638764 vs. 0.136526 [40.472 seconds]
# Generator Checkpoint Saved [173 / 200]
# Discriminator Checkpoint Saved [173 / 200]
# No. of sample images stored: [175]
# Epoch [174 / 200], batch [127 / 246]: average loss generator vs. discrim.: 707.698598 vs. 7.443904 [22.11 seconds]
# No. of sample images stored: [175]
# Epoch [174 / 200] average loss generator vs. discrim.: 5.497007 vs. 0.045465 [41.728 seconds]
# Generator Checkpoint Saved [174 / 200]
# Discriminator Checkpoint Saved [174 / 200]
# No. of sample images stored: [176]
# Epoch [175 / 200], batch [127 / 246]: average loss generator vs. discrim.: 735.719384 vs. 2.362563 [21.546 seconds]
# No. of sample images stored: [176]
# Epoch [175 / 200] average loss generator vs. discrim.: 5.895238 vs. 0.017043 [41.433 seconds]
# Generator Checkpoint Saved [175 / 200]
# Discriminator Checkpoint Saved [175 / 200]
# No. of sample images stored: [177]
# Epoch [176 / 200], batch [127 / 246]: average loss generator vs. discrim.: 796.489520 vs. 1.287603 [20.875 seconds]
# No. of sample images stored: [177]
# Epoch [176 / 200] average loss generator vs. discrim.: 6.306634 vs. 0.037589 [39.717 seconds]
# Generator Checkpoint Saved [176 / 200]
# Discriminator Checkpoint Saved [176 / 200]
# No. of sample images stored: [178]
# Epoch [177 / 200], batch [127 / 246]: average loss generator vs. discrim.: 706.639986 vs. 28.664988 [22.276 seconds]
# No. of sample images stored: [178]
# Epoch [177 / 200] average loss generator vs. discrim.: 5.630326 vs. 0.134239 [41.564 seconds]
# Generator Checkpoint Saved [177 / 200]
# Discriminator Checkpoint Saved [177 / 200]
# No. of sample images stored: [179]
# Epoch [178 / 200], batch [127 / 246]: average loss generator vs. discrim.: 760.197694 vs. 2.381239 [21.861 seconds]
# No. of sample images stored: [179]
# Epoch [178 / 200] average loss generator vs. discrim.: 6.030232 vs. 0.016125 [41.065 seconds]
# Generator Checkpoint Saved [178 / 200]
# Discriminator Checkpoint Saved [178 / 200]
# No. of sample images stored: [180]
# Epoch [179 / 200], batch [127 / 246]: average loss generator vs. discrim.: 738.607978 vs. 17.992052 [22.333 seconds]
# No. of sample images stored: [180]
# Epoch [179 / 200] average loss generator vs. discrim.: 5.900691 vs. 0.088415 [41.605 seconds]
# Generator Checkpoint Saved [179 / 200]
# Discriminator Checkpoint Saved [179 / 200]
# No. of sample images stored: [181]
# Epoch [180 / 200], batch [127 / 246]: average loss generator vs. discrim.: 717.186287 vs. 52.303601 [21.985 seconds]
# No. of sample images stored: [181]
# Epoch [180 / 200] average loss generator vs. discrim.: 5.490197 vs. 0.260080 [41.241 seconds]
# Generator Checkpoint Saved [180 / 200]
# Discriminator Checkpoint Saved [180 / 200]
# No. of sample images stored: [182]
# Epoch [181 / 200], batch [127 / 246]: average loss generator vs. discrim.: 688.934437 vs. 7.577544 [22.808 seconds]
# No. of sample images stored: [182]
# Epoch [181 / 200] average loss generator vs. discrim.: 5.393527 vs. 0.049422 [42.136 seconds]
# Generator Checkpoint Saved [181 / 200]
# Discriminator Checkpoint Saved [181 / 200]
# No. of sample images stored: [183]
# Epoch [182 / 200], batch [127 / 246]: average loss generator vs. discrim.: 706.342862 vs. 10.352787 [22.771 seconds]
# No. of sample images stored: [183]
# Epoch [182 / 200] average loss generator vs. discrim.: 5.605673 vs. 0.064733 [41.957 seconds]
# Generator Checkpoint Saved [182 / 200]
# Discriminator Checkpoint Saved [182 / 200]
# No. of sample images stored: [184]
# Epoch [183 / 200], batch [127 / 246]: average loss generator vs. discrim.: 741.800671 vs. 2.436820 [22.578 seconds]
# No. of sample images stored: [184]
# Epoch [183 / 200] average loss generator vs. discrim.: 5.881505 vs. 0.017215 [41.526 seconds]
# Generator Checkpoint Saved [183 / 200]
# Discriminator Checkpoint Saved [183 / 200]
# No. of sample images stored: [185]
# Epoch [184 / 200], batch [127 / 246]: average loss generator vs. discrim.: 765.653849 vs. 1.859014 [22.114 seconds]
# No. of sample images stored: [185]
# Epoch [184 / 200] average loss generator vs. discrim.: 6.081089 vs. 0.012630 [41.738 seconds]
# Generator Checkpoint Saved [184 / 200]
# Discriminator Checkpoint Saved [184 / 200]
# No. of sample images stored: [186]
# Epoch [185 / 200], batch [127 / 246]: average loss generator vs. discrim.: 788.391255 vs. 1.194368 [21.855 seconds]
# No. of sample images stored: [186]
# Epoch [185 / 200] average loss generator vs. discrim.: 5.997956 vs. 0.161858 [41.507 seconds]
# Generator Checkpoint Saved [185 / 200]
# Discriminator Checkpoint Saved [185 / 200]
# No. of sample images stored: [187]
# Epoch [186 / 200], batch [127 / 246]: average loss generator vs. discrim.: 680.273211 vs. 13.324488 [22.182 seconds]
# No. of sample images stored: [187]
# Epoch [186 / 200] average loss generator vs. discrim.: 5.446301 vs. 0.080402 [41.003 seconds]
# Generator Checkpoint Saved [186 / 200]
# Discriminator Checkpoint Saved [186 / 200]
# No. of sample images stored: [188]
# Epoch [187 / 200], batch [127 / 246]: average loss generator vs. discrim.: 745.745606 vs. 10.123147 [21.499 seconds]
# No. of sample images stored: [188]
# Epoch [187 / 200] average loss generator vs. discrim.: 5.815240 vs. 0.053350 [40.598 seconds]
# Generator Checkpoint Saved [187 / 200]
# Discriminator Checkpoint Saved [187 / 200]
# No. of sample images stored: [189]
# Epoch [188 / 200], batch [127 / 246]: average loss generator vs. discrim.: 748.118756 vs. 1.689722 [21.557 seconds]
# No. of sample images stored: [189]
# Epoch [188 / 200] average loss generator vs. discrim.: 6.021189 vs. 0.014278 [41.179 seconds]
# Generator Checkpoint Saved [188 / 200]
# Discriminator Checkpoint Saved [188 / 200]
# No. of sample images stored: [190]
# Epoch [189 / 200], batch [127 / 246]: average loss generator vs. discrim.: 791.803450 vs. 1.777833 [22.366 seconds]
# No. of sample images stored: [190]
# Epoch [189 / 200] average loss generator vs. discrim.: 6.265723 vs. 0.012830 [41.664 seconds]
# Generator Checkpoint Saved [189 / 200]
# Discriminator Checkpoint Saved [189 / 200]
# No. of sample images stored: [191]
# Epoch [190 / 200], batch [127 / 246]: average loss generator vs. discrim.: 805.192573 vs. 1.113032 [21.299 seconds]
# No. of sample images stored: [191]
# Epoch [190 / 200] average loss generator vs. discrim.: 6.361049 vs. 0.010222 [40.275 seconds]
# Generator Checkpoint Saved [190 / 200]
# Discriminator Checkpoint Saved [190 / 200]
# No. of sample images stored: [192]
# Epoch [191 / 200], batch [127 / 246]: average loss generator vs. discrim.: 822.889497 vs. 1.510799 [22.266 seconds]
# No. of sample images stored: [192]
# Epoch [191 / 200] average loss generator vs. discrim.: 6.559297 vs. 0.010021 [41.345 seconds]
# Generator Checkpoint Saved [191 / 200]
# Discriminator Checkpoint Saved [191 / 200]
# No. of sample images stored: [193]
# Epoch [192 / 200], batch [127 / 246]: average loss generator vs. discrim.: 697.497972 vs. 90.242175 [22.827 seconds]
# No. of sample images stored: [193]
# Epoch [192 / 200] average loss generator vs. discrim.: 5.393373 vs. 0.421684 [42.263 seconds]
# Generator Checkpoint Saved [192 / 200]
# Discriminator Checkpoint Saved [192 / 200]
# No. of sample images stored: [194]
# Epoch [193 / 200], batch [127 / 246]: average loss generator vs. discrim.: 702.776442 vs. 5.076935 [22.248 seconds]
# No. of sample images stored: [194]
# Epoch [193 / 200] average loss generator vs. discrim.: 5.516559 vs. 0.035108 [41.632 seconds]
# Generator Checkpoint Saved [193 / 200]
# Discriminator Checkpoint Saved [193 / 200]
# No. of sample images stored: [195]
# Epoch [194 / 200], batch [127 / 246]: average loss generator vs. discrim.: 741.087748 vs. 2.594584 [22.233 seconds]
# No. of sample images stored: [195]
# Epoch [194 / 200] average loss generator vs. discrim.: 5.640260 vs. 0.085191 [41.09 seconds]
# Generator Checkpoint Saved [194 / 200]
# Discriminator Checkpoint Saved [194 / 200]
# No. of sample images stored: [196]
# Epoch [195 / 200], batch [127 / 246]: average loss generator vs. discrim.: 733.847104 vs. 2.803724 [22.587 seconds]
# No. of sample images stored: [196]
# Epoch [195 / 200] average loss generator vs. discrim.: 5.837417 vs. 0.018062 [41.757 seconds]
# Generator Checkpoint Saved [195 / 200]
# Discriminator Checkpoint Saved [195 / 200]
# No. of sample images stored: [197]
# Epoch [196 / 200], batch [127 / 246]: average loss generator vs. discrim.: 775.424131 vs. 10.498840 [21.914 seconds]
# No. of sample images stored: [197]
# Epoch [196 / 200] average loss generator vs. discrim.: 5.900498 vs. 0.082041 [41.766 seconds]
# Generator Checkpoint Saved [196 / 200]
# Discriminator Checkpoint Saved [196 / 200]
# No. of sample images stored: [198]
# Epoch [197 / 200], batch [127 / 246]: average loss generator vs. discrim.: 728.045110 vs. 13.905413 [22.426 seconds]
# No. of sample images stored: [198]
# Epoch [197 / 200] average loss generator vs. discrim.: 5.709341 vs. 0.076835 [42.218 seconds]
# Generator Checkpoint Saved [197 / 200]
# Discriminator Checkpoint Saved [197 / 200]
# No. of sample images stored: [199]
# Epoch [198 / 200], batch [127 / 246]: average loss generator vs. discrim.: 742.309179 vs. 2.294504 [21.721 seconds]
# No. of sample images stored: [199]
# Epoch [198 / 200] average loss generator vs. discrim.: 5.961108 vs. 0.015562 [41.207 seconds]
# Generator Checkpoint Saved [198 / 200]
# Discriminator Checkpoint Saved [198 / 200]
# No. of sample images stored: [200]
# Epoch [199 / 200], batch [127 / 246]: average loss generator vs. discrim.: 802.870444 vs. 1.027681 [22.357 seconds]
# No. of sample images stored: [200]
# Epoch [199 / 200] average loss generator vs. discrim.: 6.260642 vs. 0.009531 [41.651 seconds]
# Generator Checkpoint Saved [199 / 200]
# Discriminator Checkpoint Saved [199 / 200]
# No. of sample images stored: [201]
# Epoch [200 / 200], batch [127 / 246]: average loss generator vs. discrim.: 817.990752 vs. 1.301886 [22.225 seconds]
# No. of sample images stored: [201]
# Epoch [200 / 200] average loss generator vs. discrim.: 6.484921 vs. 0.008692 [42.121 seconds]
# Generator Checkpoint Saved [200 / 200]
# Discriminator Checkpoint Saved [200 / 200]

# %% [markdown]
# ### Load Checkpoints

# %%
# load models
disc_save_name = 'wikiart_dc_gen.cpt'
gen_save_name = 'wikiart_dc_disc.cpt'

path_gen = F'/content/drive/MyDrive/neural_networks/checkpoints/{gen_save_name}'
path_disc = F'/content/drive/MyDrive/neural_networks/checkpoints/{disc_save_name}'

# check whether checkpoint files exist
if os.path.isfile(path_gen) and os.path.isfile(path_disc) == True:
    checkpoint_gen = torch.load(path_gen)
    checkpoint_disc = torch.load(path_disc)

    # neural net is saved on the gpu we send it to the cpu via .to(device)
    generator = Generator().to(device)
    discriminator = Discriminator().to(device)
    # given the kernel shut done and all variables are lost
    # optimizers need to be initialised again
    gen_optimizer = torch.optim.Adam(params=generator.parameters(), 
                                     lr=learning_rate, betas=(0.5, 0.999))
    disc_optimizer = torch.optim.Adam(params=discriminator.parameters(), 
                                      lr=learning_rate, betas=(0.5, 0.999))
    generator.load_state_dict(checkpoint_gen['gen_state_dict'])
    discriminator.load_state_dict(checkpoint_disc['disc_state_dict'])
    gen_optimizer.load_state_dict(checkpoint_gen['optimizer_state_dict'])
    disc_optimizer.load_state_dict(checkpoint_disc['optimizer_state_dict'])
    epoch = checkpoint_gen['epoch']
    img_lst = checkpoint_gen['img_lst']
    img_lst_gif = checkpoint_gen['img_lst_gif']
    gen_loss_avg = checkpoint_gen['gen_loss_avg']
    disc_loss_avg = checkpoint_disc['disc_loss_avg']
else: 
    print("Checkpoint files not found or do not exist.")
    print("The neural network may have not been trained yet.")
#model_gen.eval()
# - or -
#model_gen.train()

# %%
# Out:
# torch.Size([3, 64, 64])

# %% [markdown]
# ### Figures: First and Last Image

# %%
# plot 1st image
plt.figure(figsize=(12,12))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("First Image")
plt.imshow(np.transpose(vutils.make_grid(img_lst[0].to(device), padding=2, normalize=True).cpu(),(1,2,0)))
# plot last image
plt.subplot(1,2,2)
plt.axis("off")
plt.title("Last Image")
plt.imshow(np.transpose(vutils.make_grid(img_lst[-1].to(device), padding=2, normalize=True).cpu(),(1,2,0)))

# %% [markdown]
# ### Plot: Real Images vs Generated Images

# %%
# Grab a batch of real images from the dataloader
# Plot the real images
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Real Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=5, 
                                         normalize=True).cpu(),(1,2,0)))

# Plot the fake images from the last epoch
plt.subplot(1,2,2)
plt.axis("off")
plt.title("Generated Images")
plt.imshow(np.transpose(img_lst_gif[-1].cpu().numpy(),(1,2,0)))
plt.show()

# %% [markdown]
# ### Gif: Image Generation Process

# %%
# gif from starting image to last generated image
#%%capture
# if bytes for gif are too big increase limit 
# plt.rcParams['animation.embed_limit'] = 2**128
fig = plt.figure(figsize=(8,8))
plt.axis("off")
ims = [[plt.imshow(np.transpose(i.cpu().numpy(),(1,2,0)), animated=True)] for i in img_lst_gif]
ani = animation.ArtistAnimation(fig, ims, interval=1000, repeat_delay=1000, blit=True)
HTML(ani.to_jshtml())

# %% [markdown]
# ### Training Curves

# %%
# Plot average loss per epoch
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(gen_loss_avg, linewidth=1.5)
plt.plot(disc_loss_avg, linewidth=1.5)
plt.title('Average loss per epoch', fontsize = 16)
plt.xlabel('Number of epochs', fontsize = 16)
plt.ylabel('Mean Loss', fontsize = 16)
plt.legend(['Generator', 'Discriminator'], 
           prop={'size': 14},           
            frameon=False)

# Plot loss per iteration
plt.subplot(1,2,2)
plt.plot(gen_iter_loss, linewidth=1.5)
plt.plot(disc_iter_loss, linewidth=1.5)
plt.title('Loss per iteration', fontsize = 16)
plt.xlabel('Number of iterations', fontsize = 16)
plt.ylabel('Loss', fontsize = 16)
plt.legend(['Generator', 'Discriminator'], 
           prop={'size': 14},           
            frameon=False)
plt.show()

# %% [markdown]
# ### Image Evaluation Metrics

# %% [markdown]
# Inception score

# %%
stedv, means = [], []
imgs = []
for j in range(len(img_lst)):
  for i in range(len(img_lst[j])):
    imgs.append((vutils.make_grid(img_lst[j][i].to(device), padding=2, normalize=True).cpu()))
  if (j % 20 == 0): 
    print('Image metric computed for [%d / %d]' % (j, len(img_lst)))
  mean, stdv = inception_score(imgs, cuda=True, batch_size=32, resize=True, splits=10)
  means.append(mean)
  stedv.append(stdv)
# Out:
# Image metric computed for [0 / 201]
# Downloading: "https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-1a9a5a14.pth
# HBox(children=(FloatProgress(value=0.0, max=108857766.0), HTML(value='')))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3458: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# /content/drive/MyDrive/neural_networks/modules/inception_score_pytorch/inception_score.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x).data.cpu().numpy()
# Image metric computed for [20 / 201]
# Image metric computed for [40 / 201]
# Image metric computed for [60 / 201]
# Image metric computed for [80 / 201]
# Image metric computed for [100 / 201]
# Image metric computed for [120 / 201]
# Image metric computed for [140 / 201]
# Image metric computed for [160 / 201]
# Image metric computed for [180 / 201]
# Image metric computed for [200 / 201]

# %% [markdown]
# Frechet Inception Distance

# %%
real_batch = next(iter(dataloader))
fids = []
for i in range(len(img_lst)):
  fids.append(frechet_id(img_lst[i], real_batch))
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f28ea583950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f28ea156830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f28ea2cad40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f257974aa70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f296340b290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f28ea160950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f28ea654c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f257be33560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f28ea2caef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2579d65b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f274c1b4320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f274c1b4050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# Plot average loss per epoch
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(means, linewidth=1.5)
plt.title('Inception score per epoch', fontsize = 16)
plt.xlabel('Number of epochs', fontsize = 16)
plt.ylabel('Inception score', fontsize = 16)
plt.legend(['IS'], 
           prop={'size': 14},           
            frameon=False)

# Plot loss per iteration
plt.subplot(1,2,2)
plt.plot(fids, linewidth=1.5)
plt.title('Frechet inception distance per epoch', fontsize = 16)
plt.xlabel('Number of epochs', fontsize = 16)
plt.ylabel('Frechet inception distance', fontsize = 16)
plt.legend(['FID'], 
           prop={'size': 14},           
            frameon=False)
plt.show()

# %% [markdown]
# # Fractal Compression

# %%
img = img_lst[0][0] #this can be every image from img_lst!
reshaped = np.moveaxis(img.detach().cpu().numpy(), 0,2) 
compression.test_rgb(reshaped)

# %% [markdown]
# NEvAr Metric

# %%
import tensorflow as tf
# convert pytorch tensor to np array
tensor_to_np = img_lst[110].detach().cpu().numpy()
# convert np array to tf tensor
tf_tensor = tf.convert_to_tensor(tensor_to_np)
# set it as image
img = tf_tensor
# perform tf sobel edge operation
grad_components = tf.image.sobel_edges(img)
# compute gradient magnitute 
grad_mag_components = grad_components**2
# sum magnitude components
grad_mag_square = tf.math.reduce_sum(grad_mag_components,axis=-1)
# sobel edge detected image
grad_mag_img = tf.sqrt(grad_mag_square)
# convert tf tensor to np array
tensor_img = grad_mag_img.numpy()
# plot sobel operaiton on image for testing
#plt.imshow(tensor_img[0][0])

# convert numpy image to pytorch tensor
tensor_img = torch.from_numpy(tensor_img)
# plot using pytorch

# plot original image
plt.figure(figsize=(12,12))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Original Image")
plt.imshow(np.transpose(vutils.make_grid(img_lst[110][0].to(device), padding=2, 
                                         normalize=True).cpu(),(1,2,0)))
plt.subplot(1,2,2)
plt.axis("off")
plt.title("Sobel Operation")
plt.imshow(np.transpose(vutils.make_grid(tensor_img[0][0].to(device), padding=2, 
                                         normalize=True).cpu(),(1,2,0)))

# %%
def grayscale(image):
    grey = np.mean(image, axis = 0)
    return grey
from scipy import ndimage
# image = img_lst[110][0] # single tensor image isolate from batch 
image = img_lst[110][0].detach().cpu().numpy()
image = grayscale(image)
print(image.shape)
#image = grayscale(image)
#image = img_lst[110][0].detach().cpu().numpy()
img_x = ndimage.sobel(image, 0) # sobel operation across horizontal
img_y = ndimage.sobel(image, 1) # sobel operation across vertical
sob = np.hypot(img_x, img_y)
# sob = grayscale(sob)
#sob = np.sum(sob, axis = [-1,-1,-1])
#grad_comp = np.sqrt(img_x + img_y)
#grad_comp = np.sum(grad_comp,axis=-1)
#grad_mag_sqrt = np.sum(grad_comp, axis = -1)
#grad_mag_imge = np.sqrt(grad_mag_sqrt)
#tf.math.reduce_sum(grad_comp,axis=-1)
#image_sobel = np.sqrt((img_x ** 2) + (img_y **2))
# transpose image to obtain correct dimensions
# plot
# plt.imshow(np.transpose(grad_mag_imge,(1,2,0)))
#plt.imshow(np.transpose(grad_comp,(1,2,0)))
plt.imshow(sob, cmap='gray')
# Out:
# (64, 64)

# %%
from scipy import ndimage
image = img_lst[110][0] # single tensor image isolate from batch 
#image = grayscale(image)
print(image.shape)
#image = grayscale(image)
#image = img_lst[110][0].detach().cpu().numpy()
img_x = ndimage.sobel(image, 0) # sobel operation across horizontal
img_y = ndimage.sobel(image, 1) # sobel operation across vertical
sob = np.hypot(img_x, img_y)
sob = grayscale(sob)
# sob = np.sum(sob, axis = [-1,-1,-1])
# grad_comp = np.sqrt(img_x + img_y)
# grad_comp = np.sum(grad_comp,axis=-1)
# grad_mag_sqrt = np.sum(grad_comp, axis = -1)
# grad_mag_imge = np.sqrt(grad_mag_sqrt)
# tf.math.reduce_sum(grad_comp,axis=-1)
# image_sobel = np.sqrt((img_x ** 2) + (img_y **2))
# transpose image to obtain correct dimensions
# plot
# plt.imshow(np.transpose(grad_mag_imge,(1,2,0)))
# plt.imshow(np.transpose(grad_comp,(1,2,0)))
plt.imshow(sob, cmap='gray')
# Out:
# torch.Size([3, 64, 64])

# %% [markdown]
# ### Save singles of generated images

# %%
# stores a single image
#for j in range(len(img_lst)):
#  for i in range(len(img_lst[j])):
#    torchvision.utils.save_image(img_lst[j][i], '/content/drive/MyDrive/neural_networks/wikiart_gen_imgs/%d%d.JPG' % (j,i), normalize = True)
    #imgs.append((vutils.make_grid(img_lst[j][i].to(device), padding=2, normalize=True).cpu()))
#  if (j % 20 == 0): 
#    print('Stores [%d / %d] image batches' % (j * len(img_lst[0]) , len(img_lst[0])* len(img_lst)))
# Out:
# Stores [0 / 7936] image batches
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-135-7212fa9c7bad> in <module>()
#       2 for j in range(len(img_lst)):
#       3   for i in range(len(img_lst[j])):
# ----> 4     torchvision.utils.save_image(img_lst[j][i], '/content/drive/MyDrive/neural_networks/wikiart_gen_imgs/%d%d.JPG' % (j,i), normalize = True)
#       5     #imgs.append((vutils.make_grid(img_lst[j][i].to(device), padding=2, normalize=True).cpu()))
#       6   if (j % 20 == 0):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/local/lib/python3.7/dist-packages/torchvision/utils.py in save_image(tensor, fp, format, **kwargs)
#     133     ndarr = grid.mul(255).add_(0.5).clamp_(0, 255).permute(1, 2, 0).to('cpu', torch.uint8).numpy()
#     134     im = Image.fromarray(ndarr)
# --> 135     im.save(fp, format=format)
#     136
#     137
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2129                 fp = builtins.open(filename, "r+b")
#    2130             else:
# -> 2131                 fp = builtins.open(filename, "w+b")
#    2132
#    2133         try:
#
# KeyboardInterrupt:
