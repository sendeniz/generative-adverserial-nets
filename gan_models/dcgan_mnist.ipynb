# %% [markdown]
# ### MNIST: Deep Convolutional (DC) Generative Adversarial Network (GAN)

# %% [markdown]
# ### Install/Load Dependencies

# %%
import sys
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.utils as vutils
import torchvision.utils
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation
from IPython.display import HTML
import time
from google.colab import drive
import random
from torch.autograd import Variable
from torch import autograd

# %% [markdown]
# ### Mount Google Drive

# %%
# mount drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Load Metric Modules

# %%
# load inception score metric
inception_path = '/content/drive/MyDrive/neural_networks/modules/inception_score_pytorch'
#!cat '/content/drive/MyDrive/neural_networks/modules/inception_score_pytorch/inception_score.py'
sys.path.append(inception_path)
from inception_score import inception_score
frechet_path = '/content/drive/MyDrive/neural_networks/modules/frechet_inception_distance'
#!cat '/content/drive/MyDrive/neural_networks/modules/frechet_inception_distance/frechet_inception_distance.py'
sys.path.append(frechet_path)
from frechet_inception_distance import frechet_id

# %% [markdown]
# ### Training Parameters

# %%
num_epochs = 200
batch_size = 64
learning_rate = 2e-4
use_gpu = True
img_size = 64
device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")
tolerance = 0.0001

# %% [markdown]
# ### Load MNIST Data

# %%
# set random seed
random.seed(1486438)
torch.manual_seed(1486438)

# custom transform class to add gaussian noise
class AddGaussianNoise(object):
    def __init__(self, mean=0., std=1.):
        self.std = std
        self.mean = mean
        
    def __call__(self, tensor):
        return tensor + torch.randn(tensor.size()) * self.std + self.mean
    
    def __repr__(self):
        return self.__class__.__name__ + '(mean={0}, std={1})'.format(self.mean, 
                                                                      self.std)

# define transformer for dataloader
# resize and normalize data for slight performance boost
img_transform = transforms.Compose([
    transforms.Resize((img_size, img_size)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)),
    AddGaussianNoise(0., 0.1)
    ])

train_dataset = MNIST(root='./data/MNIST', download=True, train=True, 
                      transform=img_transform)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataset = MNIST(root='./data/MNIST', download=True, train=False, 
                     transform=img_transform)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)


# Plot some images
real_batch = next(iter(train_dataloader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device), padding=2, 
                                         normalize=True).cpu(),(1,2,0)))

# %% [markdown]
# ### Custom weight initialization

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %% [markdown]
# GAN Definition
# -----------------------
# We use a convolutional generator and discriminator, which generally gives better performance than fully connected versions that have the same number of parameters.
#
# Kernel size 4 is used to avoid biasing problems described here: https://distill.pub/2016/deconv-checkerboard/

# %%
# number of channels (for gray = 1 , for RGB = 3)
nc = 1
# number/size of latent vector z for the generator input
nz = 100
# size/number of feature maps in generator
ngf = 128
# size/number of feature maps in discriminator
ndf = 128
# define fixed noise to sample images from the latent space of the generator
fixed_noise = torch.randn(64, nz, 1, 1, device=device)

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        # input to conv. lay. : length of latent vector z 
        self.deconv1 = nn.ConvTranspose2d(nz, ngf*8, 4, 1, 0, bias=False)
        self.deconv1_bn = nn.BatchNorm2d(ngf*8)
        # state size: (ngf * 8) x 4 x 4
        self.deconv2 = nn.ConvTranspose2d(ngf*8, ngf*4, 4, 2, 1, bias=False)
        self.deconv2_bn = nn.BatchNorm2d(ngf*4)
        # state size: (ngf * 4) x 8 x 8
        self.deconv3 = nn.ConvTranspose2d(ngf*4, ngf*2, 4, 2, 1, bias=False)
        self.deconv3_bn = nn.BatchNorm2d(ngf*2)
        # state size: (ngf * 2) x 16 x 16
        self.deconv4 = nn.ConvTranspose2d(ngf*2, ngf, 4, 2, 1, bias=False)
        self.deconv4_bn = nn.BatchNorm2d(ngf)
        # state size: (ngf) x 32 x 32
        self.deconv5 = nn.ConvTranspose2d(ngf, nc, 4, 2, 1, bias=False)
        # state size: (nc) x 64 x 64

    def forward(self, input):
        x = F.relu(self.deconv1(input))
        x = F.relu(self.deconv1_bn(self.deconv1(input)))
        x = F.relu(self.deconv2_bn(self.deconv2(x)))
        x = F.relu(self.deconv3_bn(self.deconv3(x)))
        x = F.relu(self.deconv4_bn(self.deconv4(x)))
        x = torch.tanh(self.deconv5(x))

        return x

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        # input to conv. lay. : (nc) x 64 x 64
        self.conv1 = nn.Conv2d(nc, ndf, 4, 2, 1, bias=False)
        self.conv1_bn = nn.BatchNorm2d(ndf)
        # state size: (ndf) x 32 x 32
        self.conv2 = nn.Conv2d(ndf, ndf*2, 4, 2, 1, bias=False)
        self.conv2_bn = nn.BatchNorm2d(ndf*2)
        # state size: (ndf * 2) x 16 x 16
        self.conv3 = nn.Conv2d(ndf*2, ndf*4, 4, 2, 1, bias=False)
        self.conv3_bn = nn.BatchNorm2d(ndf*4)
        # state size: (ndf * 4) x 8 x 8
        self.conv4 = nn.Conv2d(ndf*4, ndf*8, 4, 2, 1, bias=False)
        self.conv4_bn = nn.BatchNorm2d(ndf*8)
        # state size: (ndf * 8) x 4 x 4
        self.conv5 = nn.Conv2d(ndf*8, 1, 4, 1, 0, bias=False)

    def forward(self, input):
        x = F.leaky_relu(self.conv1(input))
        x = F.leaky_relu(self.conv1_bn(self.conv1(input)), 0.2)
        x = F.leaky_relu(self.conv2_bn(self.conv2(x)), 0.2)
        x = F.leaky_relu(self.conv3_bn(self.conv3(x)), 0.2)
        x = F.leaky_relu(self.conv4_bn(self.conv4(x)), 0.2)
        x = torch.sigmoid(self.conv5(x))
        return x
    
generator = Generator()
discriminator = Discriminator()

# Apply the weights_init function to randomly initialize all weights
#  to mean=0, stdev=0.02
#generator.apply(weights_init)
#discriminator.apply(weights_init)

device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")
generator = generator.to(device)
discriminator = discriminator.to(device)

num_params_gen = sum(p.numel() for p in generator.parameters() if p.requires_grad)
num_params_disc = sum(p.numel() for p in discriminator.parameters() if p.requires_grad)
print('Number of parameters for generator: %d and discriminator: %d' % (num_params_gen, num_params_disc))
# Out:
# Number of parameters for generator: 12654336 and discriminator: 11032320

# %% [markdown]
# ### Define Storage Location

# %%
# mount google drive for saving checkpoints
drive.mount('/content/drive')

# checkpoint generator file name
gen_save_name = 'mnist_gen.cpt'
# define location to store checkpoints for generator
path_gen = F'/content/drive/My Drive/neural_networks/checkpoints/{gen_save_name}'

# checkpoint discriminator file name
disc_save_name = 'mnist_disc.cpt'
# define location to store checkpoints for discriminator
path_disc = F'/content/drive/My Drive/neural_networks/checkpoints/{disc_save_name}'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Custom Loss

# %%
class BCE(autograd.Function):
    @staticmethod
    def forward(ctx, x , y):
        loss = torch.mean(-y * torch.clamp(torch.log(x), min = -100) - (1.0-y) * torch.clamp(torch.log(1.0 - x),min = -100))
        ctx.save_for_backward(loss,x,y)
        return loss

    @staticmethod
    def backward(ctx, grad_output):
        result,x,y, = ctx.saved_tensors
        return torch.nan_to_num(torch.clamp(-( y/x - (1-y)/(1-x) ) ,min=-1.0000e+12,max=1.0000e+12 ), nan=0.0), None

# %% [markdown]
# Train GAN
# --------

# %%
# GAN training can be unstable. In this case, the strong momentum
# for the gradient prevents convergence. One possible explanation is that the
# strong momentum does not allow the two players in the adversarial game to react
# to each other quickly enough. Decreasing beta1 (the exponential decay for the
# gradient moving average in [0,1], lower is faster decay) from the default 0.9
# to 0.5 allows for quicker reactions.
gen_optimizer = torch.optim.Adam(params=generator.parameters(), lr=learning_rate,
                                 betas=(0.5, 0.999))
disc_optimizer = torch.optim.Adam(params=discriminator.parameters(), lr=learning_rate,
                                  betas=(0.5, 0.999))
# set to training mode
generator.train()
discriminator.train()

gen_iter_loss = []
disc_iter_loss = []

gen_loss_avg = []
disc_loss_avg = []
gen_loss_avg.append(0)
disc_loss_avg.append(0)
iters = 0

# store generated images 
img_lst = []
# store generated images for gif
img_lst_gif = []

print('Training ...')
for epoch in range(num_epochs):
    # start countine time 
    start_time = time.time() 
    gen_loss_avg.append(0)
    disc_loss_avg.append(0)
    num_batches = 0
    
    for image_batch, i in train_dataloader:
        # get dataset image and create real and fake labels for use in the loss
        image_batch = image_batch.to(device)
        label_real = torch.ones(image_batch.size(0), device=device)
        label_fake = torch.zeros(image_batch.size(0), device=device)

        # generate a batch of images from samples of the latent prior
        latent = torch.randn(image_batch.size(0), nz, 1, 1, device=device)
        fake_image_batch = generator(latent)
        
        # train discriminator to correctly classify real and fake
        # (detach the computation graph of the generator and the discriminator,
        # so that gradients are not backpropagated into the generator)
        real_pred = discriminator(image_batch).squeeze()
        fake_pred = discriminator(fake_image_batch.detach()).squeeze()
        disc_loss = 0.5 * (
            BCE.apply(real_pred, label_real) +
            BCE.apply(fake_pred, label_fake))
        
        disc_optimizer.zero_grad()
        disc_loss.backward()
        disc_optimizer.step()
        
        # train generator to output an image that is classified as real
        fake_pred = discriminator(fake_image_batch).squeeze()
        gen_loss = BCE.apply(fake_pred, label_real)
        
        gen_optimizer.zero_grad()
        gen_loss.backward()
        gen_optimizer.step()
        
        # store loss per iteration
        gen_iter_loss.append(gen_loss.item())
        disc_iter_loss.append(disc_loss.item())

        # average loss per iteration to obtain average loss per epoch
        gen_loss_avg[-1] += gen_loss.item()
        disc_loss_avg[-1] += disc_loss.item()
        num_batches += 1
        # every 104 batches give print statement
        if num_batches % 104 == 0 :
            print('Epoch [%d / %d], batch [%d / %d]: average loss generator vs. discrim.: %f vs. %f [%s seconds]' %
          (epoch+1, num_epochs, num_batches, len(train_dataloader), gen_loss_avg[-1], disc_loss_avg[-1], round(time.time() - start_time,3)))
        
        # Save generated image if: 
        # 1) at the first iteration
        # 2) final epoch has been reached
        # 3) a full batch of training passed i.e one epoch has passed
        elif (iters == 1) or (epoch == num_epochs) or (iters % len(train_dataloader) == 0):
            # turn off gradient descent computation to minimize computation cost
            with torch.no_grad():
                # generate fake image from generator
                fake = generator(fixed_noise).detach().cpu()
            # store image
            img_lst.append(fake)
            # store image for gif
            img_lst_gif.append(vutils.make_grid(fake, padding=2, normalize=True))
            print('No. of sample images stored: [%d]' % len(img_lst))
        iters += 1
    gen_loss_avg[-1] /= num_batches
    disc_loss_avg[-1] /= num_batches
    # after each epoch print current epoch, generator and discriminator loss and runtime per epoch
    print('Epoch [%d / %d] average loss generator vs. discrim.: %f vs. %f [%s seconds]'  %
          (epoch+1, num_epochs, gen_loss_avg[-1], disc_loss_avg[-1], round(time.time() - start_time,3)))
    # after each epoch save generator, epochs, loss and images
    print('Generator Checkpoint Saved [%d / %d]' % (epoch + 1, num_epochs))
    torch.save({
            'epoch': epoch,
            'gen_state_dict': generator.state_dict(),
            'optimizer_state_dict': gen_optimizer.state_dict(),
            'gen_loss_avg': gen_loss_avg,
            'gen_iter_loss': gen_iter_loss,
            'img_lst':img_lst,
            'img_lst_gif': img_lst_gif,
            }, path_gen)
    # after each epoch save discriminator, epochs and loss
    # print('Discriminator Checkpoint Saved [%d / %d]' % (epoch + 1, num_epochs))
    torch.save({
            'epoch': epoch,
            'disc_state_dict': discriminator.state_dict(),
            'optimizer_state_dict': disc_optimizer.state_dict(),
            'disc_loss_avg': disc_loss_avg,
            'disc_iter_loss': disc_iter_loss,
            }, path_disc)
    # if difference between current average loss and previous average loss smaler 
    # than tolerance value stop training
    #if ( abs(disc_loss_avg[-1] - disc_loss_avg[-2]) <= tolerance) or ( abs(gen_loss_avg[-1] - gen_loss_avg[-2]) <= tolerance):
    #    print('Generator or Discriminator reached an average loss of approximately 0.')
    #    print('One of the advaseries/players won the min-max game.')
    #    print('The game is over.')
    #    break
# Out:
# Training ...
# No. of sample images stored: [1]
# No. of sample images stored: [2]
# Epoch [1 / 200], batch [104 / 938]: average loss generator vs. discrim.: 845.972128 vs. 6.921404 [19.633 seconds]
# Epoch [1 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1717.438358 vs. 27.350337 [39.223 seconds]
# Epoch [1 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2213.518766 vs. 59.794313 [58.789 seconds]
# Epoch [1 / 200], batch [416 / 938]: average loss generator vs. discrim.: 2501.926174 vs. 119.120598 [78.371 seconds]
# Epoch [1 / 200], batch [520 / 938]: average loss generator vs. discrim.: 2875.643028 vs. 150.832201 [98.001 seconds]
# Epoch [1 / 200], batch [624 / 938]: average loss generator vs. discrim.: 3632.919420 vs. 151.236715 [117.579 seconds]
# Epoch [1 / 200], batch [728 / 938]: average loss generator vs. discrim.: 4420.945443 vs. 151.314101 [137.221 seconds]
# Epoch [1 / 200], batch [832 / 938]: average loss generator vs. discrim.: 5092.776009 vs. 182.009704 [156.877 seconds]
# Epoch [1 / 200], batch [936 / 938]: average loss generator vs. discrim.: 5425.132882 vs. 211.183236 [176.538 seconds]
# Epoch [1 / 200] average loss generator vs. discrim.: 5.788252 vs. 0.225965 [176.838 seconds]
# Generator Checkpoint Saved [1 / 200]
# No. of sample images stored: [3]
# Epoch [2 / 200], batch [104 / 938]: average loss generator vs. discrim.: 399.568281 vs. 35.989819 [19.886 seconds]
# Epoch [2 / 200], batch [208 / 938]: average loss generator vs. discrim.: 802.015631 vs. 67.534984 [39.492 seconds]
# Epoch [2 / 200], batch [312 / 938]: average loss generator vs. discrim.: 1222.525870 vs. 92.280055 [59.057 seconds]
# Epoch [2 / 200], batch [416 / 938]: average loss generator vs. discrim.: 1579.556628 vs. 127.759943 [78.632 seconds]
# Epoch [2 / 200], batch [520 / 938]: average loss generator vs. discrim.: 1966.431018 vs. 163.431104 [98.211 seconds]
# Epoch [2 / 200], batch [624 / 938]: average loss generator vs. discrim.: 2330.065620 vs. 198.862665 [117.818 seconds]
# Epoch [2 / 200], batch [728 / 938]: average loss generator vs. discrim.: 2727.861380 vs. 231.191107 [137.401 seconds]
# Epoch [2 / 200], batch [832 / 938]: average loss generator vs. discrim.: 3092.752496 vs. 265.916843 [157.021 seconds]
# Epoch [2 / 200], batch [936 / 938]: average loss generator vs. discrim.: 3472.157986 vs. 298.437222 [176.595 seconds]
# Epoch [2 / 200] average loss generator vs. discrim.: 3.708699 vs. 0.318411 [176.903 seconds]
# Generator Checkpoint Saved [2 / 200]
# No. of sample images stored: [4]
# Epoch [3 / 200], batch [104 / 938]: average loss generator vs. discrim.: 382.565400 vs. 32.307042 [19.963 seconds]
# Epoch [3 / 200], batch [208 / 938]: average loss generator vs. discrim.: 784.824065 vs. 65.334849 [39.558 seconds]
# Epoch [3 / 200], batch [312 / 938]: average loss generator vs. discrim.: 1224.656447 vs. 91.453851 [59.164 seconds]
# Epoch [3 / 200], batch [416 / 938]: average loss generator vs. discrim.: 1664.462767 vs. 121.341881 [78.753 seconds]
# Epoch [3 / 200], batch [520 / 938]: average loss generator vs. discrim.: 2112.645445 vs. 154.879776 [98.354 seconds]
# Epoch [3 / 200], batch [624 / 938]: average loss generator vs. discrim.: 2541.721596 vs. 184.111338 [117.918 seconds]
# Epoch [3 / 200], batch [728 / 938]: average loss generator vs. discrim.: 3014.512288 vs. 213.974686 [137.471 seconds]
# Epoch [3 / 200], batch [832 / 938]: average loss generator vs. discrim.: 3447.777017 vs. 245.658123 [157.042 seconds]
# Epoch [3 / 200], batch [936 / 938]: average loss generator vs. discrim.: 3958.664527 vs. 271.762832 [176.589 seconds]
# Epoch [3 / 200] average loss generator vs. discrim.: 4.228045 vs. 0.290365 [176.887 seconds]
# Generator Checkpoint Saved [3 / 200]
# No. of sample images stored: [5]
# Epoch [4 / 200], batch [104 / 938]: average loss generator vs. discrim.: 484.067750 vs. 26.114448 [19.887 seconds]
# Epoch [4 / 200], batch [208 / 938]: average loss generator vs. discrim.: 975.716965 vs. 52.811807 [39.46 seconds]
# Epoch [4 / 200], batch [312 / 938]: average loss generator vs. discrim.: 1485.061853 vs. 79.117311 [59.004 seconds]
# Epoch [4 / 200], batch [416 / 938]: average loss generator vs. discrim.: 2026.872112 vs. 102.749939 [78.563 seconds]
# Epoch [4 / 200], batch [520 / 938]: average loss generator vs. discrim.: 2558.852733 vs. 128.852164 [98.121 seconds]
# Epoch [4 / 200], batch [624 / 938]: average loss generator vs. discrim.: 3076.820311 vs. 156.170158 [117.63 seconds]
# Epoch [4 / 200], batch [728 / 938]: average loss generator vs. discrim.: 3600.075123 vs. 182.647775 [137.15 seconds]
# Epoch [4 / 200], batch [832 / 938]: average loss generator vs. discrim.: 4120.152029 vs. 211.097520 [156.727 seconds]
# Epoch [4 / 200], batch [936 / 938]: average loss generator vs. discrim.: 4620.864075 vs. 238.859441 [176.27 seconds]
# Epoch [4 / 200] average loss generator vs. discrim.: 4.935823 vs. 0.254783 [176.571 seconds]
# Generator Checkpoint Saved [4 / 200]
# No. of sample images stored: [6]
# Epoch [5 / 200], batch [104 / 938]: average loss generator vs. discrim.: 526.289511 vs. 26.564983 [19.925 seconds]
# Epoch [5 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1045.727146 vs. 50.090911 [39.494 seconds]
# Epoch [5 / 200], batch [312 / 938]: average loss generator vs. discrim.: 1599.673894 vs. 77.727992 [59.044 seconds]
# Epoch [5 / 200], batch [416 / 938]: average loss generator vs. discrim.: 2135.732190 vs. 99.742882 [78.613 seconds]
# Epoch [5 / 200], batch [520 / 938]: average loss generator vs. discrim.: 2692.051909 vs. 125.735347 [98.212 seconds]
# Epoch [5 / 200], batch [624 / 938]: average loss generator vs. discrim.: 3234.366560 vs. 149.987469 [117.758 seconds]
# Epoch [5 / 200], batch [728 / 938]: average loss generator vs. discrim.: 3752.546249 vs. 178.222249 [137.303 seconds]
# Epoch [5 / 200], batch [832 / 938]: average loss generator vs. discrim.: 4284.657945 vs. 200.207362 [156.862 seconds]
# Epoch [5 / 200], batch [936 / 938]: average loss generator vs. discrim.: 4838.385859 vs. 222.864360 [176.418 seconds]
# Epoch [5 / 200] average loss generator vs. discrim.: 5.167697 vs. 0.237913 [176.717 seconds]
# Generator Checkpoint Saved [5 / 200]
# No. of sample images stored: [7]
# Epoch [6 / 200], batch [104 / 938]: average loss generator vs. discrim.: 536.369414 vs. 25.242191 [19.909 seconds]
# Epoch [6 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1059.725446 vs. 55.859185 [39.446 seconds]
# Epoch [6 / 200], batch [312 / 938]: average loss generator vs. discrim.: 1611.389155 vs. 78.665810 [59.039 seconds]
# Epoch [6 / 200], batch [416 / 938]: average loss generator vs. discrim.: 2168.012410 vs. 102.117942 [78.619 seconds]
# Epoch [6 / 200], batch [520 / 938]: average loss generator vs. discrim.: 2715.385289 vs. 123.320950 [98.155 seconds]
# Epoch [6 / 200], batch [624 / 938]: average loss generator vs. discrim.: 3267.072041 vs. 147.416738 [117.685 seconds]
# Epoch [6 / 200], batch [728 / 938]: average loss generator vs. discrim.: 3823.125032 vs. 173.493119 [137.212 seconds]
# Epoch [6 / 200], batch [832 / 938]: average loss generator vs. discrim.: 4375.519610 vs. 198.256934 [156.767 seconds]
# Epoch [6 / 200], batch [936 / 938]: average loss generator vs. discrim.: 4945.496397 vs. 224.914100 [176.29 seconds]
# Epoch [6 / 200] average loss generator vs. discrim.: 5.282684 vs. 0.239901 [176.594 seconds]
# Generator Checkpoint Saved [6 / 200]
# No. of sample images stored: [8]
# Epoch [7 / 200], batch [104 / 938]: average loss generator vs. discrim.: 549.778917 vs. 23.296670 [19.891 seconds]
# Epoch [7 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1072.689790 vs. 48.054056 [39.464 seconds]
# Epoch [7 / 200], batch [312 / 938]: average loss generator vs. discrim.: 1603.074905 vs. 74.162103 [59.04 seconds]
# Epoch [7 / 200], batch [416 / 938]: average loss generator vs. discrim.: 2191.574950 vs. 96.575044 [78.613 seconds]
# Epoch [7 / 200], batch [520 / 938]: average loss generator vs. discrim.: 2756.435465 vs. 116.341671 [98.191 seconds]
# Epoch [7 / 200], batch [624 / 938]: average loss generator vs. discrim.: 3343.872406 vs. 140.243099 [117.773 seconds]
# Epoch [7 / 200], batch [728 / 938]: average loss generator vs. discrim.: 3914.970267 vs. 160.422819 [137.39 seconds]
# Epoch [7 / 200], batch [832 / 938]: average loss generator vs. discrim.: 4540.054002 vs. 180.964585 [156.93 seconds]
# Epoch [7 / 200], batch [936 / 938]: average loss generator vs. discrim.: 5116.597590 vs. 206.817016 [176.479 seconds]
# Epoch [7 / 200] average loss generator vs. discrim.: 5.474674 vs. 0.221993 [176.79 seconds]
# Generator Checkpoint Saved [7 / 200]
# No. of sample images stored: [9]
# Epoch [8 / 200], batch [104 / 938]: average loss generator vs. discrim.: 612.220188 vs. 20.696984 [19.96 seconds]
# Epoch [8 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1219.372035 vs. 40.648583 [39.538 seconds]
# Epoch [8 / 200], batch [312 / 938]: average loss generator vs. discrim.: 1814.174081 vs. 64.739031 [59.108 seconds]
# Epoch [8 / 200], batch [416 / 938]: average loss generator vs. discrim.: 2443.823977 vs. 86.214587 [78.625 seconds]
# Epoch [8 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3089.244426 vs. 108.483661 [98.188 seconds]
# Epoch [8 / 200], batch [624 / 938]: average loss generator vs. discrim.: 3777.485911 vs. 127.998835 [117.73 seconds]
# Epoch [8 / 200], batch [728 / 938]: average loss generator vs. discrim.: 4463.792288 vs. 146.280076 [137.289 seconds]
# Epoch [8 / 200], batch [832 / 938]: average loss generator vs. discrim.: 5109.130274 vs. 166.280350 [156.811 seconds]
# Epoch [8 / 200], batch [936 / 938]: average loss generator vs. discrim.: 5748.033021 vs. 186.165860 [176.353 seconds]
# Epoch [8 / 200] average loss generator vs. discrim.: 6.142037 vs. 0.198551 [176.654 seconds]
# Generator Checkpoint Saved [8 / 200]
# No. of sample images stored: [10]
# Epoch [9 / 200], batch [104 / 938]: average loss generator vs. discrim.: 707.700380 vs. 19.379841 [19.925 seconds]
# Epoch [9 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1405.112929 vs. 37.973519 [39.453 seconds]
# Epoch [9 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2103.580384 vs. 57.378395 [58.981 seconds]
# Epoch [9 / 200], batch [416 / 938]: average loss generator vs. discrim.: 2787.659579 vs. 81.300290 [78.502 seconds]
# Epoch [9 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3482.617218 vs. 97.708141 [98.019 seconds]
# Epoch [9 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4184.089941 vs. 118.360035 [117.535 seconds]
# Epoch [9 / 200], batch [728 / 938]: average loss generator vs. discrim.: 4897.088312 vs. 135.830653 [137.022 seconds]
# Epoch [9 / 200], batch [832 / 938]: average loss generator vs. discrim.: 5648.469473 vs. 154.625578 [156.561 seconds]
# Epoch [9 / 200], batch [936 / 938]: average loss generator vs. discrim.: 6407.399358 vs. 175.767393 [176.12 seconds]
# Epoch [9 / 200] average loss generator vs. discrim.: 6.841222 vs. 0.188041 [176.419 seconds]
# Generator Checkpoint Saved [9 / 200]
# No. of sample images stored: [11]
# Epoch [10 / 200], batch [104 / 938]: average loss generator vs. discrim.: 744.688854 vs. 23.464792 [19.843 seconds]
# Epoch [10 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1422.028878 vs. 43.550116 [39.4 seconds]
# Epoch [10 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2166.178460 vs. 61.829252 [58.932 seconds]
# Epoch [10 / 200], batch [416 / 938]: average loss generator vs. discrim.: 2907.399921 vs. 81.021280 [78.459 seconds]
# Epoch [10 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3669.453458 vs. 98.598200 [98.02 seconds]
# Epoch [10 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4417.868746 vs. 114.811358 [117.582 seconds]
# Epoch [10 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5169.721996 vs. 135.517155 [137.139 seconds]
# Epoch [10 / 200], batch [832 / 938]: average loss generator vs. discrim.: 5929.167534 vs. 157.890117 [156.669 seconds]
# Epoch [10 / 200], batch [936 / 938]: average loss generator vs. discrim.: 6674.933378 vs. 178.186997 [176.174 seconds]
# Epoch [10 / 200] average loss generator vs. discrim.: 7.129153 vs. 0.190346 [176.471 seconds]
# Generator Checkpoint Saved [10 / 200]
# No. of sample images stored: [12]
# Epoch [11 / 200], batch [104 / 938]: average loss generator vs. discrim.: 765.229251 vs. 16.444518 [19.947 seconds]
# Epoch [11 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1550.321542 vs. 34.118847 [39.487 seconds]
# Epoch [11 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2329.417118 vs. 53.958053 [59.023 seconds]
# Epoch [11 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3076.668392 vs. 72.106210 [78.551 seconds]
# Epoch [11 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3868.636937 vs. 92.324572 [98.053 seconds]
# Epoch [11 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4631.804286 vs. 105.436096 [117.596 seconds]
# Epoch [11 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5493.637493 vs. 121.143065 [137.101 seconds]
# Epoch [11 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6338.329505 vs. 135.249724 [156.686 seconds]
# Epoch [11 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7233.257642 vs. 146.437150 [176.25 seconds]
# Epoch [11 / 200] average loss generator vs. discrim.: 7.733498 vs. 0.156143 [176.546 seconds]
# Generator Checkpoint Saved [11 / 200]
# No. of sample images stored: [13]
# Epoch [12 / 200], batch [104 / 938]: average loss generator vs. discrim.: 867.605449 vs. 22.546082 [19.882 seconds]
# Epoch [12 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1663.893344 vs. 38.319631 [39.43 seconds]
# Epoch [12 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2445.871538 vs. 59.551422 [58.942 seconds]
# Epoch [12 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3355.787946 vs. 74.060535 [78.455 seconds]
# Epoch [12 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4186.606246 vs. 92.269595 [97.985 seconds]
# Epoch [12 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5044.786037 vs. 107.453665 [117.561 seconds]
# Epoch [12 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5824.693907 vs. 124.001536 [137.115 seconds]
# Epoch [12 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6774.893823 vs. 139.992525 [156.657 seconds]
# Epoch [12 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7763.983493 vs. 152.859581 [176.219 seconds]
# Epoch [12 / 200] average loss generator vs. discrim.: 8.303033 vs. 0.162969 [176.514 seconds]
# Generator Checkpoint Saved [12 / 200]
# No. of sample images stored: [14]
# Epoch [13 / 200], batch [104 / 938]: average loss generator vs. discrim.: 866.502383 vs. 19.932201 [19.947 seconds]
# Epoch [13 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1690.992202 vs. 42.337105 [39.51 seconds]
# Epoch [13 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2470.429538 vs. 60.730835 [59.035 seconds]
# Epoch [13 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3302.329479 vs. 76.706017 [78.592 seconds]
# Epoch [13 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4134.268618 vs. 92.972281 [98.152 seconds]
# Epoch [13 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4972.825636 vs. 108.969053 [117.712 seconds]
# Epoch [13 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5784.063532 vs. 128.405358 [137.252 seconds]
# Epoch [13 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6673.657201 vs. 145.365229 [156.761 seconds]
# Epoch [13 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7509.431718 vs. 160.372732 [176.275 seconds]
# Epoch [13 / 200] average loss generator vs. discrim.: 8.036624 vs. 0.172872 [176.575 seconds]
# Generator Checkpoint Saved [13 / 200]
# No. of sample images stored: [15]
# Epoch [14 / 200], batch [104 / 938]: average loss generator vs. discrim.: 984.881006 vs. 15.704635 [19.976 seconds]
# Epoch [14 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1870.003550 vs. 31.519524 [39.538 seconds]
# Epoch [14 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2785.526303 vs. 49.251805 [59.099 seconds]
# Epoch [14 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3700.847252 vs. 63.436143 [78.672 seconds]
# Epoch [14 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4553.030895 vs. 83.346928 [98.223 seconds]
# Epoch [14 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5473.429549 vs. 103.143130 [117.777 seconds]
# Epoch [14 / 200], batch [728 / 938]: average loss generator vs. discrim.: 6358.383441 vs. 119.163195 [137.296 seconds]
# Epoch [14 / 200], batch [832 / 938]: average loss generator vs. discrim.: 7245.421254 vs. 133.936258 [156.812 seconds]
# Epoch [14 / 200], batch [936 / 938]: average loss generator vs. discrim.: 8160.183900 vs. 154.340782 [176.317 seconds]
# Epoch [14 / 200] average loss generator vs. discrim.: 8.710788 vs. 0.164587 [176.622 seconds]
# Generator Checkpoint Saved [14 / 200]
# No. of sample images stored: [16]
# Epoch [15 / 200], batch [104 / 938]: average loss generator vs. discrim.: 885.700702 vs. 17.985744 [19.935 seconds]
# Epoch [15 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1746.075199 vs. 38.106370 [39.501 seconds]
# Epoch [15 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2645.493795 vs. 56.388072 [59.031 seconds]
# Epoch [15 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3461.801167 vs. 73.445980 [78.578 seconds]
# Epoch [15 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4397.840094 vs. 86.592817 [98.138 seconds]
# Epoch [15 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5326.901474 vs. 103.091838 [117.658 seconds]
# Epoch [15 / 200], batch [728 / 938]: average loss generator vs. discrim.: 6158.585637 vs. 124.203277 [137.198 seconds]
# Epoch [15 / 200], batch [832 / 938]: average loss generator vs. discrim.: 7038.558636 vs. 139.935062 [156.73 seconds]
# Epoch [15 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7949.574480 vs. 159.204450 [176.269 seconds]
# Epoch [15 / 200] average loss generator vs. discrim.: 8.501657 vs. 0.169907 [176.564 seconds]
# Generator Checkpoint Saved [15 / 200]
# No. of sample images stored: [17]
# Epoch [16 / 200], batch [104 / 938]: average loss generator vs. discrim.: 877.636170 vs. 17.205329 [19.951 seconds]
# Epoch [16 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1771.883237 vs. 33.470546 [39.519 seconds]
# Epoch [16 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2702.735629 vs. 49.205980 [59.08 seconds]
# Epoch [16 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3625.335960 vs. 69.120535 [78.605 seconds]
# Epoch [16 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4479.072010 vs. 82.998918 [98.179 seconds]
# Epoch [16 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5382.285485 vs. 100.411299 [117.718 seconds]
# Epoch [16 / 200], batch [728 / 938]: average loss generator vs. discrim.: 6303.606740 vs. 120.839588 [137.285 seconds]
# Epoch [16 / 200], batch [832 / 938]: average loss generator vs. discrim.: 7092.977650 vs. 138.307952 [156.898 seconds]
# Epoch [16 / 200], batch [936 / 938]: average loss generator vs. discrim.: 8010.769047 vs. 151.052854 [176.453 seconds]
# Epoch [16 / 200] average loss generator vs. discrim.: 8.564494 vs. 0.161391 [176.762 seconds]
# Generator Checkpoint Saved [16 / 200]
# No. of sample images stored: [18]
# Epoch [17 / 200], batch [104 / 938]: average loss generator vs. discrim.: 876.488736 vs. 18.230812 [20.021 seconds]
# Epoch [17 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1739.840717 vs. 33.998285 [39.649 seconds]
# Epoch [17 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2651.772349 vs. 54.701862 [59.214 seconds]
# Epoch [17 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3560.792654 vs. 70.726758 [78.756 seconds]
# Epoch [17 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4461.204779 vs. 81.954514 [98.277 seconds]
# Epoch [17 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5499.765781 vs. 97.147972 [117.826 seconds]
# Epoch [17 / 200], batch [728 / 938]: average loss generator vs. discrim.: 6549.251354 vs. 112.533880 [137.344 seconds]
# Epoch [17 / 200], batch [832 / 938]: average loss generator vs. discrim.: 7536.364128 vs. 130.480202 [156.891 seconds]
# Epoch [17 / 200], batch [936 / 938]: average loss generator vs. discrim.: 8453.018638 vs. 147.249840 [176.417 seconds]
# Epoch [17 / 200] average loss generator vs. discrim.: 9.028361 vs. 0.157171 [176.718 seconds]
# Generator Checkpoint Saved [17 / 200]
# No. of sample images stored: [19]
# Epoch [18 / 200], batch [104 / 938]: average loss generator vs. discrim.: 939.433011 vs. 16.705453 [19.981 seconds]
# Epoch [18 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1903.190344 vs. 31.424421 [39.526 seconds]
# Epoch [18 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2777.960625 vs. 53.053723 [59.065 seconds]
# Epoch [18 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3661.266587 vs. 72.419514 [78.609 seconds]
# Epoch [18 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4555.543445 vs. 91.103219 [98.187 seconds]
# Epoch [18 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5412.557929 vs. 107.829949 [117.787 seconds]
# Epoch [18 / 200], batch [728 / 938]: average loss generator vs. discrim.: 6354.324931 vs. 121.071666 [137.335 seconds]
# Epoch [18 / 200], batch [832 / 938]: average loss generator vs. discrim.: 7284.090889 vs. 136.774654 [156.867 seconds]
# Epoch [18 / 200], batch [936 / 938]: average loss generator vs. discrim.: 8275.598476 vs. 156.870855 [176.424 seconds]
# Epoch [18 / 200] average loss generator vs. discrim.: 8.838114 vs. 0.167293 [176.721 seconds]
# Generator Checkpoint Saved [18 / 200]
# No. of sample images stored: [20]
# Epoch [19 / 200], batch [104 / 938]: average loss generator vs. discrim.: 930.544453 vs. 19.411697 [19.943 seconds]
# Epoch [19 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1800.674873 vs. 33.737434 [39.507 seconds]
# Epoch [19 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2766.078719 vs. 47.795952 [59.075 seconds]
# Epoch [19 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3653.564973 vs. 66.340707 [78.621 seconds]
# Epoch [19 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4613.822947 vs. 84.132471 [98.196 seconds]
# Epoch [19 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5562.275477 vs. 100.992581 [117.763 seconds]
# Epoch [19 / 200], batch [728 / 938]: average loss generator vs. discrim.: 6442.222943 vs. 115.754258 [137.336 seconds]
# Epoch [19 / 200], batch [832 / 938]: average loss generator vs. discrim.: 7329.694789 vs. 130.446081 [156.904 seconds]
# Epoch [19 / 200], batch [936 / 938]: average loss generator vs. discrim.: 8263.136880 vs. 146.255574 [176.487 seconds]
# Epoch [19 / 200] average loss generator vs. discrim.: 8.819993 vs. 0.155945 [176.793 seconds]
# Generator Checkpoint Saved [19 / 200]
# No. of sample images stored: [21]
# Epoch [20 / 200], batch [104 / 938]: average loss generator vs. discrim.: 851.676020 vs. 21.948280 [19.937 seconds]
# Epoch [20 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1715.955679 vs. 38.695372 [39.499 seconds]
# Epoch [20 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2674.598051 vs. 54.069939 [59.075 seconds]
# Epoch [20 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3590.816815 vs. 73.236373 [78.612 seconds]
# Epoch [20 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4498.737732 vs. 87.939211 [98.197 seconds]
# Epoch [20 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5447.838441 vs. 101.960692 [117.763 seconds]
# Epoch [20 / 200], batch [728 / 938]: average loss generator vs. discrim.: 6425.211832 vs. 116.631248 [137.348 seconds]
# Epoch [20 / 200], batch [832 / 938]: average loss generator vs. discrim.: 7387.052699 vs. 127.300871 [156.9 seconds]
# Epoch [20 / 200], batch [936 / 938]: average loss generator vs. discrim.: 8452.649981 vs. 143.031009 [176.449 seconds]
# Epoch [20 / 200] average loss generator vs. discrim.: 9.027295 vs. 0.152648 [176.748 seconds]
# Generator Checkpoint Saved [20 / 200]
# No. of sample images stored: [22]
# Epoch [21 / 200], batch [104 / 938]: average loss generator vs. discrim.: 1010.584217 vs. 12.467714 [19.903 seconds]
# Epoch [21 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1911.853410 vs. 29.258285 [39.444 seconds]
# Epoch [21 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2906.822942 vs. 43.329560 [58.989 seconds]
# Epoch [21 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3865.164854 vs. 58.887274 [78.577 seconds]
# Epoch [21 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4864.207034 vs. 71.749317 [98.123 seconds]
# Epoch [21 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5866.776943 vs. 86.559895 [117.638 seconds]
# Epoch [21 / 200], batch [728 / 938]: average loss generator vs. discrim.: 6866.925864 vs. 103.554601 [137.189 seconds]
# Epoch [21 / 200], batch [832 / 938]: average loss generator vs. discrim.: 7805.913175 vs. 119.383519 [156.739 seconds]
# Epoch [21 / 200], batch [936 / 938]: average loss generator vs. discrim.: 8768.650612 vs. 134.366894 [176.279 seconds]
# Epoch [21 / 200] average loss generator vs. discrim.: 9.364034 vs. 0.143336 [176.576 seconds]
# Generator Checkpoint Saved [21 / 200]
# No. of sample images stored: [23]
# Epoch [22 / 200], batch [104 / 938]: average loss generator vs. discrim.: 937.947951 vs. 16.225382 [19.994 seconds]
# Epoch [22 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1910.376204 vs. 32.062546 [39.568 seconds]
# Epoch [22 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2850.716987 vs. 46.262611 [59.107 seconds]
# Epoch [22 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3866.898173 vs. 61.309948 [78.625 seconds]
# Epoch [22 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4816.454007 vs. 76.374670 [98.187 seconds]
# Epoch [22 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5706.003267 vs. 94.341384 [117.768 seconds]
# Epoch [22 / 200], batch [728 / 938]: average loss generator vs. discrim.: 6636.454805 vs. 106.592938 [137.326 seconds]
# Epoch [22 / 200], batch [832 / 938]: average loss generator vs. discrim.: 7547.115370 vs. 122.191601 [156.9 seconds]
# Epoch [22 / 200], batch [936 / 938]: average loss generator vs. discrim.: 8527.464292 vs. 139.900613 [176.436 seconds]
# Epoch [22 / 200] average loss generator vs. discrim.: 9.106793 vs. 0.150211 [176.733 seconds]
# Generator Checkpoint Saved [22 / 200]
# No. of sample images stored: [24]
# Epoch [23 / 200], batch [104 / 938]: average loss generator vs. discrim.: 982.885150 vs. 16.743637 [20.008 seconds]
# Epoch [23 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1907.961450 vs. 32.616644 [39.54 seconds]
# Epoch [23 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2826.372306 vs. 47.325710 [59.088 seconds]
# Epoch [23 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3806.647476 vs. 63.517546 [78.669 seconds]
# Epoch [23 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4676.056781 vs. 81.174709 [98.247 seconds]
# Epoch [23 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5591.501770 vs. 93.859140 [117.824 seconds]
# Epoch [23 / 200], batch [728 / 938]: average loss generator vs. discrim.: 6567.182681 vs. 106.050478 [137.423 seconds]
# Epoch [23 / 200], batch [832 / 938]: average loss generator vs. discrim.: 7482.610194 vs. 122.605981 [156.953 seconds]
# Epoch [23 / 200], batch [936 / 938]: average loss generator vs. discrim.: 8374.126820 vs. 137.121184 [176.515 seconds]
# Epoch [23 / 200] average loss generator vs. discrim.: 8.954763 vs. 0.146373 [176.815 seconds]
# Generator Checkpoint Saved [23 / 200]
# No. of sample images stored: [25]
# Epoch [24 / 200], batch [104 / 938]: average loss generator vs. discrim.: 919.509089 vs. 14.600127 [19.925 seconds]
# Epoch [24 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1820.228243 vs. 30.046304 [39.463 seconds]
# Epoch [24 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2650.939601 vs. 48.302244 [59.02 seconds]
# Epoch [24 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3486.655805 vs. 63.481734 [78.551 seconds]
# Epoch [24 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4399.171755 vs. 80.856172 [98.085 seconds]
# Epoch [24 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5251.487182 vs. 96.222938 [117.607 seconds]
# Epoch [24 / 200], batch [728 / 938]: average loss generator vs. discrim.: 6110.736205 vs. 113.550070 [137.137 seconds]
# Epoch [24 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6953.671349 vs. 130.683037 [156.66 seconds]
# Epoch [24 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7790.989910 vs. 148.255464 [176.217 seconds]
# Epoch [24 / 200] average loss generator vs. discrim.: 8.317577 vs. 0.158277 [176.516 seconds]
# Generator Checkpoint Saved [24 / 200]
# No. of sample images stored: [26]
# Epoch [25 / 200], batch [104 / 938]: average loss generator vs. discrim.: 840.931095 vs. 13.606216 [20.003 seconds]
# Epoch [25 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1633.457639 vs. 31.039042 [39.548 seconds]
# Epoch [25 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2429.881424 vs. 44.362703 [59.131 seconds]
# Epoch [25 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3274.006967 vs. 62.464708 [78.687 seconds]
# Epoch [25 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4116.199199 vs. 78.185657 [98.203 seconds]
# Epoch [25 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4872.788109 vs. 100.132580 [117.738 seconds]
# Epoch [25 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5634.014919 vs. 116.797846 [137.265 seconds]
# Epoch [25 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6477.045384 vs. 132.524656 [156.815 seconds]
# Epoch [25 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7228.827748 vs. 150.187332 [176.349 seconds]
# Epoch [25 / 200] average loss generator vs. discrim.: 7.724942 vs. 0.160648 [176.645 seconds]
# Generator Checkpoint Saved [25 / 200]
# No. of sample images stored: [27]
# Epoch [26 / 200], batch [104 / 938]: average loss generator vs. discrim.: 816.139574 vs. 15.827767 [19.96 seconds]
# Epoch [26 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1674.599254 vs. 30.811068 [39.624 seconds]
# Epoch [26 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2548.147279 vs. 47.136670 [59.297 seconds]
# Epoch [26 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3326.846320 vs. 61.585692 [78.947 seconds]
# Epoch [26 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4182.709000 vs. 79.536144 [98.512 seconds]
# Epoch [26 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5005.828928 vs. 97.471528 [118.095 seconds]
# Epoch [26 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5854.687075 vs. 111.438448 [137.691 seconds]
# Epoch [26 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6686.424325 vs. 128.319708 [157.273 seconds]
# Epoch [26 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7487.499689 vs. 148.935842 [176.871 seconds]
# Epoch [26 / 200] average loss generator vs. discrim.: 7.995865 vs. 0.159251 [177.174 seconds]
# Generator Checkpoint Saved [26 / 200]
# No. of sample images stored: [28]
# Epoch [27 / 200], batch [104 / 938]: average loss generator vs. discrim.: 843.982882 vs. 16.199173 [20.08 seconds]
# Epoch [27 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1715.971504 vs. 30.818062 [39.674 seconds]
# Epoch [27 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2622.648570 vs. 44.177374 [59.268 seconds]
# Epoch [27 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3530.175266 vs. 61.129762 [78.838 seconds]
# Epoch [27 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4390.847244 vs. 78.995814 [98.387 seconds]
# Epoch [27 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5197.031395 vs. 95.130320 [117.955 seconds]
# Epoch [27 / 200], batch [728 / 938]: average loss generator vs. discrim.: 6016.179426 vs. 111.130804 [137.529 seconds]
# Epoch [27 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6907.005090 vs. 126.135419 [157.135 seconds]
# Epoch [27 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7780.622526 vs. 145.909318 [176.722 seconds]
# Epoch [27 / 200] average loss generator vs. discrim.: 8.307187 vs. 0.156519 [177.017 seconds]
# Generator Checkpoint Saved [27 / 200]
# No. of sample images stored: [29]
# Epoch [28 / 200], batch [104 / 938]: average loss generator vs. discrim.: 812.005366 vs. 14.134913 [19.944 seconds]
# Epoch [28 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1633.407816 vs. 28.630255 [39.527 seconds]
# Epoch [28 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2523.420362 vs. 45.624833 [59.123 seconds]
# Epoch [28 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3361.158532 vs. 60.802253 [78.692 seconds]
# Epoch [28 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4192.439155 vs. 73.266027 [98.268 seconds]
# Epoch [28 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5135.506835 vs. 87.771163 [117.895 seconds]
# Epoch [28 / 200], batch [728 / 938]: average loss generator vs. discrim.: 6012.923321 vs. 99.803802 [137.45 seconds]
# Epoch [28 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6864.352732 vs. 113.904581 [157.028 seconds]
# Epoch [28 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7722.289620 vs. 133.677155 [176.615 seconds]
# Epoch [28 / 200] average loss generator vs. discrim.: 8.243307 vs. 0.142580 [176.915 seconds]
# Generator Checkpoint Saved [28 / 200]
# No. of sample images stored: [30]
# Epoch [29 / 200], batch [104 / 938]: average loss generator vs. discrim.: 785.557671 vs. 13.573101 [20.039 seconds]
# Epoch [29 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1681.778651 vs. 27.572095 [39.63 seconds]
# Epoch [29 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2467.093192 vs. 43.558839 [59.2 seconds]
# Epoch [29 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3330.064969 vs. 61.452571 [78.793 seconds]
# Epoch [29 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4093.527741 vs. 77.888283 [98.379 seconds]
# Epoch [29 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4870.092740 vs. 95.597870 [117.954 seconds]
# Epoch [29 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5671.898104 vs. 112.994383 [137.499 seconds]
# Epoch [29 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6431.810718 vs. 126.889358 [157.087 seconds]
# Epoch [29 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7224.544463 vs. 140.465584 [176.691 seconds]
# Epoch [29 / 200] average loss generator vs. discrim.: 7.717130 vs. 0.150209 [176.988 seconds]
# Generator Checkpoint Saved [29 / 200]
# No. of sample images stored: [31]
# Epoch [30 / 200], batch [104 / 938]: average loss generator vs. discrim.: 848.634802 vs. 14.495045 [20.05 seconds]
# Epoch [30 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1743.704297 vs. 28.029152 [39.643 seconds]
# Epoch [30 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2640.524295 vs. 42.538777 [59.205 seconds]
# Epoch [30 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3569.327528 vs. 59.276975 [78.764 seconds]
# Epoch [30 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4464.567757 vs. 73.074626 [98.31 seconds]
# Epoch [30 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5378.180443 vs. 85.118088 [117.856 seconds]
# Epoch [30 / 200], batch [728 / 938]: average loss generator vs. discrim.: 6264.419242 vs. 102.798313 [137.454 seconds]
# Epoch [30 / 200], batch [832 / 938]: average loss generator vs. discrim.: 7141.178879 vs. 115.040814 [157.018 seconds]
# Epoch [30 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7913.752229 vs. 131.855168 [176.566 seconds]
# Epoch [30 / 200] average loss generator vs. discrim.: 8.449405 vs. 0.140641 [176.864 seconds]
# Generator Checkpoint Saved [30 / 200]
# No. of sample images stored: [32]
# Epoch [31 / 200], batch [104 / 938]: average loss generator vs. discrim.: 885.312854 vs. 17.017981 [20.125 seconds]
# Epoch [31 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1659.400520 vs. 29.105116 [39.697 seconds]
# Epoch [31 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2540.274097 vs. 43.346386 [59.261 seconds]
# Epoch [31 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3382.457223 vs. 56.507400 [78.798 seconds]
# Epoch [31 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4240.520676 vs. 69.461952 [98.33 seconds]
# Epoch [31 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5120.069731 vs. 85.331988 [117.93 seconds]
# Epoch [31 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5951.751030 vs. 100.610905 [137.555 seconds]
# Epoch [31 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6831.143467 vs. 111.483975 [157.131 seconds]
# Epoch [31 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7681.893421 vs. 127.107808 [176.692 seconds]
# Epoch [31 / 200] average loss generator vs. discrim.: 8.207903 vs. 0.135558 [176.992 seconds]
# Generator Checkpoint Saved [31 / 200]
# No. of sample images stored: [33]
# Epoch [32 / 200], batch [104 / 938]: average loss generator vs. discrim.: 914.286011 vs. 13.552423 [20.101 seconds]
# Epoch [32 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1737.485561 vs. 23.617481 [39.641 seconds]
# Epoch [32 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2718.633239 vs. 33.897504 [59.203 seconds]
# Epoch [32 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3726.825803 vs. 48.065263 [78.768 seconds]
# Epoch [32 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4552.082126 vs. 65.714891 [98.341 seconds]
# Epoch [32 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5362.108586 vs. 77.911614 [117.911 seconds]
# Epoch [32 / 200], batch [728 / 938]: average loss generator vs. discrim.: 6169.377675 vs. 95.257903 [137.43 seconds]
# Epoch [32 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6962.896986 vs. 107.809519 [156.954 seconds]
# Epoch [32 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7677.394921 vs. 125.077817 [176.523 seconds]
# Epoch [32 / 200] average loss generator vs. discrim.: 8.195076 vs. 0.133460 [176.824 seconds]
# Generator Checkpoint Saved [32 / 200]
# No. of sample images stored: [34]
# Epoch [33 / 200], batch [104 / 938]: average loss generator vs. discrim.: 750.242606 vs. 17.254969 [20.11 seconds]
# Epoch [33 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1531.371993 vs. 30.860837 [39.632 seconds]
# Epoch [33 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2315.869934 vs. 43.613406 [59.194 seconds]
# Epoch [33 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3130.428729 vs. 57.531191 [78.716 seconds]
# Epoch [33 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3986.669950 vs. 68.416359 [98.296 seconds]
# Epoch [33 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4889.398920 vs. 82.438648 [117.87 seconds]
# Epoch [33 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5792.545835 vs. 95.052355 [137.477 seconds]
# Epoch [33 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6659.789806 vs. 112.769700 [157.056 seconds]
# Epoch [33 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7506.740727 vs. 129.935266 [176.623 seconds]
# Epoch [33 / 200] average loss generator vs. discrim.: 8.019444 vs. 0.138683 [176.926 seconds]
# Generator Checkpoint Saved [33 / 200]
# No. of sample images stored: [35]
# Epoch [34 / 200], batch [104 / 938]: average loss generator vs. discrim.: 794.131055 vs. 14.327398 [20.159 seconds]
# Epoch [34 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1562.676220 vs. 29.770882 [39.734 seconds]
# Epoch [34 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2338.397894 vs. 42.329413 [59.314 seconds]
# Epoch [34 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3175.550607 vs. 56.077600 [78.915 seconds]
# Epoch [34 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4022.317262 vs. 69.990355 [98.436 seconds]
# Epoch [34 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4815.009628 vs. 93.030420 [117.989 seconds]
# Epoch [34 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5582.444697 vs. 105.798566 [137.539 seconds]
# Epoch [34 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6434.501172 vs. 116.058243 [157.138 seconds]
# Epoch [34 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7303.127811 vs. 127.642270 [176.713 seconds]
# Epoch [34 / 200] average loss generator vs. discrim.: 7.814275 vs. 0.136101 [177.008 seconds]
# Generator Checkpoint Saved [34 / 200]
# No. of sample images stored: [36]
# Epoch [35 / 200], batch [104 / 938]: average loss generator vs. discrim.: 854.242708 vs. 17.033956 [20.11 seconds]
# Epoch [35 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1621.654607 vs. 28.670126 [39.673 seconds]
# Epoch [35 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2422.342325 vs. 42.990689 [59.207 seconds]
# Epoch [35 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3184.313214 vs. 58.100637 [78.774 seconds]
# Epoch [35 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3938.174127 vs. 72.170379 [98.338 seconds]
# Epoch [35 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4697.081749 vs. 83.915191 [117.906 seconds]
# Epoch [35 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5480.886672 vs. 97.416702 [137.452 seconds]
# Epoch [35 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6264.642171 vs. 114.490311 [156.961 seconds]
# Epoch [35 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7106.778847 vs. 125.191083 [176.527 seconds]
# Epoch [35 / 200] average loss generator vs. discrim.: 7.591257 vs. 0.133753 [176.828 seconds]
# Generator Checkpoint Saved [35 / 200]
# No. of sample images stored: [37]
# Epoch [36 / 200], batch [104 / 938]: average loss generator vs. discrim.: 909.525784 vs. 13.488778 [20.111 seconds]
# Epoch [36 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1811.038208 vs. 27.053230 [39.701 seconds]
# Epoch [36 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2665.213564 vs. 39.302745 [59.256 seconds]
# Epoch [36 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3492.218181 vs. 53.502686 [78.803 seconds]
# Epoch [36 / 200], batch [520 / 938]: average loss generator vs. discrim.: 4312.760444 vs. 69.323054 [98.331 seconds]
# Epoch [36 / 200], batch [624 / 938]: average loss generator vs. discrim.: 5093.328382 vs. 85.575577 [117.881 seconds]
# Epoch [36 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5920.333990 vs. 101.234223 [137.489 seconds]
# Epoch [36 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6671.904980 vs. 114.366151 [157.075 seconds]
# Epoch [36 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7423.147747 vs. 130.555092 [176.653 seconds]
# Epoch [36 / 200] average loss generator vs. discrim.: 7.924111 vs. 0.139802 [176.954 seconds]
# Generator Checkpoint Saved [36 / 200]
# No. of sample images stored: [38]
# Epoch [37 / 200], batch [104 / 938]: average loss generator vs. discrim.: 717.121731 vs. 12.240445 [20.07 seconds]
# Epoch [37 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1501.724948 vs. 24.037719 [39.685 seconds]
# Epoch [37 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2319.915870 vs. 39.243605 [59.344 seconds]
# Epoch [37 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3046.181153 vs. 53.467598 [78.943 seconds]
# Epoch [37 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3790.484378 vs. 69.002172 [98.59 seconds]
# Epoch [37 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4592.791889 vs. 79.300554 [118.22 seconds]
# Epoch [37 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5457.120651 vs. 90.788028 [137.863 seconds]
# Epoch [37 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6315.337499 vs. 102.263713 [157.504 seconds]
# Epoch [37 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7202.283439 vs. 114.219162 [177.132 seconds]
# Epoch [37 / 200] average loss generator vs. discrim.: 7.691210 vs. 0.122245 [177.436 seconds]
# Generator Checkpoint Saved [37 / 200]
# No. of sample images stored: [39]
# Epoch [38 / 200], batch [104 / 938]: average loss generator vs. discrim.: 777.607549 vs. 15.297064 [20.179 seconds]
# Epoch [38 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1662.225869 vs. 28.370424 [39.75 seconds]
# Epoch [38 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2437.259753 vs. 46.164572 [59.357 seconds]
# Epoch [38 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3155.530672 vs. 65.840624 [78.925 seconds]
# Epoch [38 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3869.183396 vs. 82.239877 [98.489 seconds]
# Epoch [38 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4627.029006 vs. 96.206803 [118.055 seconds]
# Epoch [38 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5397.034008 vs. 106.728573 [137.588 seconds]
# Epoch [38 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6201.451982 vs. 122.264808 [157.166 seconds]
# Epoch [38 / 200], batch [936 / 938]: average loss generator vs. discrim.: 6965.071739 vs. 132.579516 [176.715 seconds]
# Epoch [38 / 200] average loss generator vs. discrim.: 7.439010 vs. 0.141366 [177.018 seconds]
# Generator Checkpoint Saved [38 / 200]
# No. of sample images stored: [40]
# Epoch [39 / 200], batch [104 / 938]: average loss generator vs. discrim.: 799.963327 vs. 15.338721 [20.189 seconds]
# Epoch [39 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1600.309201 vs. 29.548652 [39.823 seconds]
# Epoch [39 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2444.321572 vs. 41.173286 [59.46 seconds]
# Epoch [39 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3187.318257 vs. 57.135619 [79.047 seconds]
# Epoch [39 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3994.593380 vs. 72.114777 [98.646 seconds]
# Epoch [39 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4809.529211 vs. 86.490822 [118.278 seconds]
# Epoch [39 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5540.350228 vs. 102.666876 [137.861 seconds]
# Epoch [39 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6344.502726 vs. 114.003575 [157.465 seconds]
# Epoch [39 / 200], batch [936 / 938]: average loss generator vs. discrim.: 7150.275105 vs. 125.834768 [177.084 seconds]
# Epoch [39 / 200] average loss generator vs. discrim.: 7.638484 vs. 0.134351 [177.385 seconds]
# Generator Checkpoint Saved [39 / 200]
# No. of sample images stored: [41]
# Epoch [40 / 200], batch [104 / 938]: average loss generator vs. discrim.: 760.161860 vs. 14.341385 [20.183 seconds]
# Epoch [40 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1588.966830 vs. 24.883177 [39.778 seconds]
# ...
# Epoch [188 / 200], batch [104 / 938]: average loss generator vs. discrim.: 762.005765 vs. 6.025102 [20.737 seconds]
# Epoch [188 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1504.797397 vs. 22.817397 [40.537 seconds]
# Epoch [188 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2266.107583 vs. 30.523005 [60.15 seconds]
# Epoch [188 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3044.743455 vs. 37.511301 [79.754 seconds]
# Epoch [188 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3842.293874 vs. 42.769047 [99.4 seconds]
# Epoch [188 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4571.420239 vs. 48.717428 [119.022 seconds]
# Epoch [188 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5289.579108 vs. 54.933922 [138.64 seconds]
# Epoch [188 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6070.161583 vs. 64.228782 [158.253 seconds]
# Epoch [188 / 200], batch [936 / 938]: average loss generator vs. discrim.: 6782.788473 vs. 72.638875 [177.858 seconds]
# Epoch [188 / 200] average loss generator vs. discrim.: 7.243819 vs. 0.077546 [178.161 seconds]
# Generator Checkpoint Saved [188 / 200]
# No. of sample images stored: [190]
# Epoch [189 / 200], batch [104 / 938]: average loss generator vs. discrim.: 737.141754 vs. 7.077058 [20.482 seconds]
# Epoch [189 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1490.719333 vs. 13.934996 [40.411 seconds]
# Epoch [189 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2310.139323 vs. 19.502082 [60.02 seconds]
# Epoch [189 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3067.415098 vs. 26.906897 [79.617 seconds]
# Epoch [189 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3840.276113 vs. 33.880893 [99.195 seconds]
# Epoch [189 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4603.704078 vs. 48.169579 [118.8 seconds]
# Epoch [189 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5349.382429 vs. 57.703482 [138.409 seconds]
# Epoch [189 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6075.186843 vs. 65.692445 [158.068 seconds]
# Epoch [189 / 200], batch [936 / 938]: average loss generator vs. discrim.: 6839.269031 vs. 72.114601 [177.677 seconds]
# Epoch [189 / 200] average loss generator vs. discrim.: 7.304539 vs. 0.077229 [177.982 seconds]
# Generator Checkpoint Saved [189 / 200]
# No. of sample images stored: [191]
# Epoch [190 / 200], batch [104 / 938]: average loss generator vs. discrim.: 730.558587 vs. 7.519468 [20.524 seconds]
# Epoch [190 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1465.433060 vs. 14.541477 [40.529 seconds]
# Epoch [190 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2208.443111 vs. 20.766921 [60.147 seconds]
# Epoch [190 / 200], batch [416 / 938]: average loss generator vs. discrim.: 2955.749779 vs. 30.159332 [79.758 seconds]
# Epoch [190 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3685.040355 vs. 37.449574 [99.39 seconds]
# Epoch [190 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4443.612010 vs. 44.201101 [119.032 seconds]
# Epoch [190 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5194.357984 vs. 50.326246 [138.615 seconds]
# Epoch [190 / 200], batch [832 / 938]: average loss generator vs. discrim.: 5965.741291 vs. 57.177243 [158.217 seconds]
# Epoch [190 / 200], batch [936 / 938]: average loss generator vs. discrim.: 6808.709320 vs. 70.004049 [177.842 seconds]
# Epoch [190 / 200] average loss generator vs. discrim.: 7.270973 vs. 0.074725 [178.145 seconds]
# Generator Checkpoint Saved [190 / 200]
# No. of sample images stored: [192]
# Epoch [191 / 200], batch [104 / 938]: average loss generator vs. discrim.: 761.244216 vs. 6.902953 [20.673 seconds]
# Epoch [191 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1549.448447 vs. 14.020513 [40.578 seconds]
# Epoch [191 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2313.196687 vs. 22.526971 [60.151 seconds]
# Epoch [191 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3048.589749 vs. 28.997593 [79.725 seconds]
# Epoch [191 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3811.117208 vs. 35.484496 [99.31 seconds]
# Epoch [191 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4590.884104 vs. 43.303633 [118.955 seconds]
# Epoch [191 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5310.900529 vs. 51.611587 [138.548 seconds]
# Epoch [191 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6069.934284 vs. 59.872437 [158.146 seconds]
# Epoch [191 / 200], batch [936 / 938]: average loss generator vs. discrim.: 6819.642439 vs. 67.041001 [177.761 seconds]
# Epoch [191 / 200] average loss generator vs. discrim.: 7.283021 vs. 0.071760 [178.062 seconds]
# Generator Checkpoint Saved [191 / 200]
# No. of sample images stored: [193]
# Epoch [192 / 200], batch [104 / 938]: average loss generator vs. discrim.: 754.787009 vs. 9.047179 [20.4 seconds]
# Epoch [192 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1493.228326 vs. 14.524616 [40.477 seconds]
# Epoch [192 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2258.172640 vs. 20.067493 [60.089 seconds]
# Epoch [192 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3046.898699 vs. 24.301338 [79.739 seconds]
# Epoch [192 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3853.560402 vs. 29.180959 [99.334 seconds]
# Epoch [192 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4695.222162 vs. 45.576517 [118.929 seconds]
# Epoch [192 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5403.416811 vs. 54.893052 [138.482 seconds]
# Epoch [192 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6078.806568 vs. 61.497859 [158.073 seconds]
# Epoch [192 / 200], batch [936 / 938]: average loss generator vs. discrim.: 6834.137950 vs. 68.821746 [177.674 seconds]
# Epoch [192 / 200] average loss generator vs. discrim.: 7.303589 vs. 0.073861 [177.977 seconds]
# Generator Checkpoint Saved [192 / 200]
# No. of sample images stored: [194]
# Epoch [193 / 200], batch [104 / 938]: average loss generator vs. discrim.: 752.709195 vs. 7.737028 [20.609 seconds]
# Epoch [193 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1499.310992 vs. 16.028314 [40.435 seconds]
# Epoch [193 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2266.086453 vs. 22.390496 [60.062 seconds]
# Epoch [193 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3020.514506 vs. 28.379333 [79.678 seconds]
# Epoch [193 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3740.704402 vs. 37.128133 [99.278 seconds]
# Epoch [193 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4557.447995 vs. 44.539868 [118.936 seconds]
# Epoch [193 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5301.382878 vs. 51.227760 [138.537 seconds]
# Epoch [193 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6024.150127 vs. 59.231824 [158.174 seconds]
# Epoch [193 / 200], batch [936 / 938]: average loss generator vs. discrim.: 6766.985945 vs. 66.220733 [177.774 seconds]
# Epoch [193 / 200] average loss generator vs. discrim.: 7.230857 vs. 0.070809 [178.084 seconds]
# Generator Checkpoint Saved [193 / 200]
# No. of sample images stored: [195]
# Epoch [194 / 200], batch [104 / 938]: average loss generator vs. discrim.: 784.168552 vs. 6.834888 [20.601 seconds]
# Epoch [194 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1545.372208 vs. 15.711838 [40.41 seconds]
# Epoch [194 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2311.082698 vs. 28.626353 [60.06 seconds]
# Epoch [194 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3078.720610 vs. 34.978734 [79.661 seconds]
# Epoch [194 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3805.124337 vs. 41.242927 [99.249 seconds]
# Epoch [194 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4546.285264 vs. 46.363662 [118.855 seconds]
# Epoch [194 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5314.794147 vs. 52.978180 [138.407 seconds]
# Epoch [194 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6095.460562 vs. 58.552954 [157.973 seconds]
# Epoch [194 / 200], batch [936 / 938]: average loss generator vs. discrim.: 6848.150470 vs. 73.808059 [177.567 seconds]
# Epoch [194 / 200] average loss generator vs. discrim.: 7.321879 vs. 0.079936 [177.866 seconds]
# Generator Checkpoint Saved [194 / 200]
# No. of sample images stored: [196]
# Epoch [195 / 200], batch [104 / 938]: average loss generator vs. discrim.: 767.920769 vs. 10.046972 [19.985 seconds]
# Epoch [195 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1498.214545 vs. 17.843214 [39.994 seconds]
# Epoch [195 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2308.876336 vs. 26.884959 [59.935 seconds]
# Epoch [195 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3052.288875 vs. 35.908673 [79.542 seconds]
# Epoch [195 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3783.766914 vs. 43.745282 [99.152 seconds]
# Epoch [195 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4515.450970 vs. 56.944901 [118.772 seconds]
# Epoch [195 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5232.721769 vs. 65.715295 [138.353 seconds]
# Epoch [195 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6016.080830 vs. 72.392795 [158.008 seconds]
# Epoch [195 / 200], batch [936 / 938]: average loss generator vs. discrim.: 6752.448091 vs. 77.931885 [177.645 seconds]
# Epoch [195 / 200] average loss generator vs. discrim.: 7.213582 vs. 0.083798 [177.95 seconds]
# Generator Checkpoint Saved [195 / 200]
# No. of sample images stored: [197]
# Epoch [196 / 200], batch [104 / 938]: average loss generator vs. discrim.: 720.718538 vs. 5.471955 [20.437 seconds]
# Epoch [196 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1497.016383 vs. 17.079601 [40.37 seconds]
# Epoch [196 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2235.153669 vs. 25.338090 [59.948 seconds]
# Epoch [196 / 200], batch [416 / 938]: average loss generator vs. discrim.: 2993.722427 vs. 32.711887 [79.586 seconds]
# Epoch [196 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3697.244375 vs. 39.933817 [99.213 seconds]
# Epoch [196 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4446.010668 vs. 45.849945 [118.832 seconds]
# Epoch [196 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5196.184577 vs. 52.894362 [138.446 seconds]
# Epoch [196 / 200], batch [832 / 938]: average loss generator vs. discrim.: 5940.131574 vs. 59.775045 [158.076 seconds]
# Epoch [196 / 200], batch [936 / 938]: average loss generator vs. discrim.: 6735.111046 vs. 65.803096 [177.717 seconds]
# Epoch [196 / 200] average loss generator vs. discrim.: 7.195921 vs. 0.070215 [178.021 seconds]
# Generator Checkpoint Saved [196 / 200]
# No. of sample images stored: [198]
# Epoch [197 / 200], batch [104 / 938]: average loss generator vs. discrim.: 765.100325 vs. 4.562918 [20.251 seconds]
# Epoch [197 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1527.068141 vs. 10.971042 [40.406 seconds]
# Epoch [197 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2301.034948 vs. 19.891756 [60.004 seconds]
# Epoch [197 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3092.401160 vs. 28.309996 [79.635 seconds]
# Epoch [197 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3838.795383 vs. 36.355730 [99.267 seconds]
# Epoch [197 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4592.531678 vs. 44.830784 [118.866 seconds]
# Epoch [197 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5332.155754 vs. 51.525549 [138.515 seconds]
# Epoch [197 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6070.206013 vs. 59.102099 [158.131 seconds]
# Epoch [197 / 200], batch [936 / 938]: average loss generator vs. discrim.: 6825.359078 vs. 67.672633 [177.766 seconds]
# Epoch [197 / 200] average loss generator vs. discrim.: 7.290889 vs. 0.072311 [178.074 seconds]
# Generator Checkpoint Saved [197 / 200]
# No. of sample images stored: [199]
# Epoch [198 / 200], batch [104 / 938]: average loss generator vs. discrim.: 782.355664 vs. 6.011750 [20.233 seconds]
# Epoch [198 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1542.418463 vs. 15.589098 [40.374 seconds]
# Epoch [198 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2264.328550 vs. 21.469989 [59.995 seconds]
# Epoch [198 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3018.154558 vs. 26.869199 [79.616 seconds]
# Epoch [198 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3797.505526 vs. 36.894195 [99.21 seconds]
# Epoch [198 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4611.799527 vs. 43.694766 [118.828 seconds]
# Epoch [198 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5430.455723 vs. 48.714745 [138.466 seconds]
# Epoch [198 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6189.903985 vs. 55.357576 [158.095 seconds]
# Epoch [198 / 200], batch [936 / 938]: average loss generator vs. discrim.: 6937.908844 vs. 61.414899 [177.71 seconds]
# Epoch [198 / 200] average loss generator vs. discrim.: 7.412279 vs. 0.065549 [178.013 seconds]
# Generator Checkpoint Saved [198 / 200]
# No. of sample images stored: [200]
# Epoch [199 / 200], batch [104 / 938]: average loss generator vs. discrim.: 792.452168 vs. 8.863309 [20.606 seconds]
# Epoch [199 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1555.953578 vs. 15.149301 [40.445 seconds]
# Epoch [199 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2326.516427 vs. 22.183570 [60.045 seconds]
# Epoch [199 / 200], batch [416 / 938]: average loss generator vs. discrim.: 3104.277595 vs. 28.734758 [79.68 seconds]
# Epoch [199 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3905.915780 vs. 39.387336 [99.306 seconds]
# Epoch [199 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4624.987744 vs. 47.431058 [118.911 seconds]
# Epoch [199 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5332.659954 vs. 54.184770 [138.527 seconds]
# Epoch [199 / 200], batch [832 / 938]: average loss generator vs. discrim.: 6101.980582 vs. 61.887055 [158.155 seconds]
# Epoch [199 / 200], batch [936 / 938]: average loss generator vs. discrim.: 6844.805216 vs. 70.157490 [177.763 seconds]
# Epoch [199 / 200] average loss generator vs. discrim.: 7.311704 vs. 0.074828 [178.065 seconds]
# Generator Checkpoint Saved [199 / 200]
# No. of sample images stored: [201]
# Epoch [200 / 200], batch [104 / 938]: average loss generator vs. discrim.: 764.460776 vs. 7.109213 [20.339 seconds]
# Epoch [200 / 200], batch [208 / 938]: average loss generator vs. discrim.: 1516.615507 vs. 16.482468 [40.405 seconds]
# Epoch [200 / 200], batch [312 / 938]: average loss generator vs. discrim.: 2253.051232 vs. 22.758511 [60.004 seconds]
# Epoch [200 / 200], batch [416 / 938]: average loss generator vs. discrim.: 2976.955472 vs. 31.396313 [79.63 seconds]
# Epoch [200 / 200], batch [520 / 938]: average loss generator vs. discrim.: 3735.789654 vs. 37.539168 [99.214 seconds]
# Epoch [200 / 200], batch [624 / 938]: average loss generator vs. discrim.: 4508.732475 vs. 43.873560 [118.845 seconds]
# Epoch [200 / 200], batch [728 / 938]: average loss generator vs. discrim.: 5231.374999 vs. 50.003066 [138.465 seconds]
# Epoch [200 / 200], batch [832 / 938]: average loss generator vs. discrim.: 5967.045382 vs. 55.803462 [158.098 seconds]
# Epoch [200 / 200], batch [936 / 938]: average loss generator vs. discrim.: 6713.421002 vs. 64.652207 [177.72 seconds]
# Epoch [200 / 200] average loss generator vs. discrim.: 7.168072 vs. 0.069000 [178.023 seconds]
# Generator Checkpoint Saved [200 / 200]

# %% [markdown]
# ### Load Checkpoints

# %%
# load models
disc_save_name = 'mnist_disc.cpt'
gen_save_name = 'mnist_gen.cpt'

path_gen = F'/content/drive/My Drive/neural_networks/checkpoints/{gen_save_name}'
path_disc = F'/content/drive/My Drive/neural_networks/checkpoints/{disc_save_name}'

# check whether checkpoint files exist
if os.path.isfile(path_gen) and os.path.isfile(path_disc) == True:
    checkpoint_gen = torch.load(path_gen)
    checkpoint_disc = torch.load(path_disc)

    # neural net is saved on the gpu we send it to the cpu via .to(device)
    generator = Generator().to(device)
    discriminator = Discriminator().to(device)
    # given the kernel shut done and all variables are lost
    # optimizers need to be initialised again
    gen_optimizer = torch.optim.Adam(params=generator.parameters(), 
                                     lr=learning_rate, 
                                     betas=(0.5, 0.999))
    disc_optimizer = torch.optim.Adam(params=discriminator.parameters(), 
                                      lr=learning_rate, 
                                      betas=(0.5, 0.999))
    generator.load_state_dict(checkpoint_gen['gen_state_dict'])
    discriminator.load_state_dict(checkpoint_disc['disc_state_dict'])
    gen_optimizer.load_state_dict(checkpoint_gen['optimizer_state_dict'])
    disc_optimizer.load_state_dict(checkpoint_disc['optimizer_state_dict'])
    epoch = checkpoint_gen['epoch']
    img_lst = checkpoint_gen['img_lst']
    img_lst_gif = checkpoint_gen['img_lst_gif']
    gen_loss_avg = checkpoint_gen['gen_loss_avg']
    disc_loss_avg = checkpoint_disc['disc_loss_avg']
    gen_iter_loss = checkpoint_gen['gen_iter_loss']
    disc_iter_loss = checkpoint_disc['disc_iter_loss']
else: 
    print("Checkpoint files not found or do not exist.")
    print("The neural network may have not been trained yet.")
# model_gen.eval()
# - or -
# model_gen.train()

# %% [markdown]
# ### Figures: First and Last Image

# %%
# plot of generated image
# plot 1st image
plt.figure(figsize=(12,12))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("First Image")
plt.imshow(np.transpose(vutils.make_grid(img_lst[0].to(device), padding=2, 
                                         normalize=True).cpu(),(1,2,0)))
# plot last image
plt.subplot(1,2,2)
plt.axis("off")
plt.title("Last Image")
plt.imshow(np.transpose(vutils.make_grid(img_lst[-1].to(device), padding=2, 
                                         normalize=True).cpu(),(1,2,0)))

# %% [markdown]
# ### Plot: Batch of Real vs. Generated Images

# %%
# Grab a batch of real images from the dataloader
real_batch = next(iter(train_dataloader))

# Plot the real images
plt.figure(figsize=(12,12))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Real Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], 
                                         padding=5, normalize=True).cpu(),(1,2,0)))

# Plot the fake images from the last epoch
plt.subplot(1,2,2)
plt.axis("off")
plt.title("Generated Images")
plt.imshow(np.transpose(img_lst_gif[-1].cpu().numpy(),(1,2,0)))
plt.show()

# %% [markdown]
# ### Gif: Image Generation Process

# %%
# gif from starting image to last generated image
# if bytes for gif are too big increase limit 
# plt.rcParams['animation.embed_limit'] = 2**128
fig = plt.figure(figsize=(6,6))
plt.axis("off")
ims = [[plt.imshow(np.transpose(i.cpu().numpy(),(1,2,0)), animated=True)] for i in img_lst_gif]
ani = animation.ArtistAnimation(fig, ims, interval=1000, repeat_delay=1000, blit=True)
HTML(ani.to_jshtml())

# %% [markdown]
# ### Training Curves
# --------------------

# %%
# Plot average loss per epoch
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(gen_loss_avg, linewidth=1.5)
plt.plot(disc_loss_avg, linewidth=1.5)
plt.title('Average loss per epoch', fontsize = 16)
plt.xlabel('Number of epochs', fontsize = 16)
plt.ylabel('Mean Loss', fontsize = 16)
plt.legend(['Generator', 'Discriminator'], 
           prop={'size': 14},           
            frameon=False)

# Plot loss per iteration
plt.subplot(1,2,2)
plt.plot(gen_iter_loss, linewidth=1.5)
plt.plot(disc_iter_loss, linewidth=1.5)
plt.title('Loss per iteration', fontsize = 16)
plt.xlabel('Number of iterations', fontsize = 16)
plt.ylabel('Loss', fontsize = 16)
plt.legend(['Generator', 'Discriminator'], 
           prop={'size': 14},           
            frameon=False)
plt.show()

# %% [markdown]
# ### Image Evaluation Metrics

# %% [markdown]
# Inception Score

# %%
# %%capture
stedv, means = [], []
imgs = []
for j in range(len(img_lst)):
  for i in range(len(img_lst[j])):
    imgs.append((vutils.make_grid(img_lst[j][i].to(device), padding=2, 
                                  normalize=True).cpu()))
  if (j % 20 == 0): 
    print('Average inception score computed for [%d / %d] epochs' % (j, len(img_lst)))
  mean, stdv = inception_score(imgs, cuda=True, batch_size=64, resize=True, splits=10)
  means.append(mean)
  stedv.append(stdv)

# %% [markdown]
# Fechet Inception Distance

# %%
# %%capture
real_batch = next(iter(train_dataloader))
fids = []
for i in range(len(img_lst)):
  fids.append(frechet_id(img_lst[i], real_batch))

# %%
# Plot average loss per epoch
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(means, linewidth=1.5)
plt.title('Inception score per epoch', fontsize = 16)
plt.xlabel('Number of epochs', fontsize = 16)
plt.ylabel('Inception score', fontsize = 16)
plt.legend(['IS'], 
           prop={'size': 14},           
            frameon=False)

# Plot loss per iteration
plt.subplot(1,2,2)
plt.plot(fids, linewidth=1.5)
plt.title('Frechet inception distance per epoch', fontsize = 16)
plt.xlabel('Number of epochs', fontsize = 16)
plt.ylabel('Frechet inception distance', fontsize = 16)
plt.legend(['FID'], 
           prop={'size': 14},           
            frameon=False)
plt.show()

# %% [markdown]
# ### Save Single Generatred Image

# %%
# stores a single image
for j in range(len(img_lst)):
  for i in range(len(img_lst[j])):
    torchvision.utils.save_image(img_lst[j][i], '/content/drive/MyDrive/neural_networks/mnist_gen_imgs/%d%d.JPG' % (j,i), normalize = True)
    #imgs.append((vutils.make_grid(img_lst[j][i].to(device), padding=2, normalize=True).cpu()))
  if (j % 20 == 0): 
    print('Stores [%d / %d] image batches' % (j * len(img_lst[0]) , len(img_lst[0])* len(img_lst)))
# Out:
# Stores [0 / 6400] image batches
# Stores [1280 / 6400] image batches
# Stores [2560 / 6400] image batches
# Stores [3840 / 6400] image batches
# Stores [5120 / 6400] image batches

# %% [markdown]
# ### Save Batch of Images

# %%
# stores an entire batch of images
for i in range(len(img_lst)):
  torchvision.utils.save_image(img_lst[i], '/content/drive/MyDrive/neural_networks/test_images/%d.JPG' % i, normalize = True)
  if (i % 20 == 0):
    print('Finished storing [%d / %d] image batches' % (i, len(img_lst)))
# Out:
# Finished storing [0 / 100] image batches
# Finished storing [20 / 100] image batches
# Finished storing [40 / 100] image batches
# Finished storing [60 / 100] image batches
# Finished storing [80 / 100] image batches
